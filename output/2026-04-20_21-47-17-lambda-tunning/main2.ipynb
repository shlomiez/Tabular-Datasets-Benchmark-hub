# %% [markdown]
# # STG and LSPIN Evaluation Notebook
#
# This notebook runs the iterative feature-reduction experiment across the six loaded datasets:
# - Breast, defined as "hard" dataset
# - madelon, defined as "hard" dataset
# - SMK-CAN-187, defined as "medium" dataset
# - colon, defined as "medium" dataset
# - leukemia, defined as "easy" dataset
# - RELATHE, defined as "easy" dataset
#
# ## Workflow
# 1. Initialize notebook environment.
# 2. Configure paths and load datasets.
# 3. Apply reproducibility settings (seeding).
# 4. Run STG/LSPIN feature selection + ExtraTrees evaluation in 5-fold CV.
# 5. Plot and save train/test curves.
# 6. Write outputs into a dedicated output folder.
# 7. Re-run safety checks for repeatability.

# %% [markdown]
# ## Initialize Imports, Libraries, and Global Configuration

# %%
# %pip install featselectlib lifelines
# Out:
# Requirement already satisfied: featselectlib in /usr/local/lib/python3.12/dist-packages (0.1.0)
# Requirement already satisfied: lifelines in /usr/local/lib/python3.12/dist-packages (0.30.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from featselectlib) (2.10.0+cpu)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from featselectlib) (1.6.1)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from featselectlib) (2.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from featselectlib) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from featselectlib) (3.10.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from lifelines) (2.0.2)
# Requirement already satisfied: pandas<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from lifelines) (2.2.2)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.12/dist-packages (from lifelines) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.12/dist-packages (from lifelines) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from lifelines) (1.2.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (2.19.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (4.15.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->featselectlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=2.1->lifelines) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=2.1->lifelines) (2026.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->featselectlib) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf->featselectlib) (6.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->featselectlib) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->featselectlib) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->featselectlib) (3.25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->featselectlib) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->featselectlib) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->featselectlib) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->featselectlib) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->featselectlib) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->featselectlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->featselectlib) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->featselectlib) (3.0.3)

# %%
from __future__ import annotations
import collections as _collections
import os
import random
from pathlib import Path
from typing import Any, Dict, Mapping, MutableMapping, Sequence, Tuple
from collections import abc as _collections_abc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from scipy import sparse as sp
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler

for _alias in ("Callable", "Iterable", "Mapping", "MutableMapping", "Sequence", "Set"):
    if not hasattr(_collections, _alias):
        setattr(_collections, _alias, getattr(_collections_abc, _alias))

try:
    import google.colab  # type: ignore
    IN_COLAB = True
except Exception:
    IN_COLAB = False

if IN_COLAB:
    from google.colab import drive  # type: ignore
    drive.mount("/content/drive", force_remount=False)

PROJECT_DIR_CANDIDATES = [
    Path("/content/drive/MyDrive/Colab Notebooks/Thesis"),
    Path.cwd(),
]
BASE_DIR = next((p for p in PROJECT_DIR_CANDIDATES if p.exists()), Path.cwd())
os.chdir(BASE_DIR)

try:
    from featselectlib.supervised_feature_selection.Lspin import DataSetMeta, Lspin
    from featselectlib.supervised_feature_selection.stg.python.stg import STG
except ModuleNotFoundError as exc:
    raise ModuleNotFoundError(
        "Missing dependency 'featselectlib'. Install it first (for example in Colab: !pip install featselectlib)."
    ) from exc

OUTPUT_DIR = BASE_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
date_and_time = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M-%S")
OUTPUT_DIR = OUTPUT_DIR / date_and_time
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Environment: {'Google Colab' if IN_COLAB else 'Local'}")
print(f"Base directory: {BASE_DIR}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Torch device: {DEVICE}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Environment: Google Colab
# Base directory: /content/drive/MyDrive/Colab Notebooks/Thesis
# Output directory: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_21-47-17
# Torch device: cpu

# %%
# ==============================================================================
# GLOBAL EXPERIMENT CONFIGURATION
# ==============================================================================
# 1. Select the evaluation method.
# Options: "features_ratio", "lamda_tuning"
feature_selection_method = "lamda_tuning"

# OUTPUT_DIR = Path("/content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_11-11-34")
# print(f"Output directory: {OUTPUT_DIR}")
# 2. Select which datasets you want to evaluate.
DEFAULT_DATASET_NAMES = ["madelon", "RELATHE"]  # Hard/easy datasets combinations 

# 3. Features ratio configuration (only used if "features_ratio" is selected)

# Ratios evaluated: 100%, 90%, ..., 10%, 5%
feature_ratios = [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.05]

# 4. Lambda tuning configuration (only used if "lamda_tuning" is selected)
# Default fallback sequence for datasets without specific ranges
lambda_values = [0.1, 0.5, 1.0, 5.0, 10.0, 50.0, 100.0]

# Paired STG/LSPIN lambda ranges per dataset (using geomspace to distribute points log-linearly)
lambda_ranges_by_dataset = {
    "madelon": {
        "stg": np.geomspace(0.9, 3, num=7).tolist(),
        "lspin": np.geomspace(0.00001, 10, num=7).tolist(),
    },
    "RELATHE": {
        "stg": np.geomspace(10, 17, num=7).tolist(),
        "lspin": np.geomspace(0.00001, 100, num=7).tolist(),
    },
}

if feature_selection_method == "features_ratio":
    print("Feature selection method: features_ratio")
else:
    print("Feature selection method: lamda_tuning")
    print(f"Dataset-specific lambda ranges mapped: {list(lambda_ranges_by_dataset.keys())}")
    print(f"lambda ranges for datasets without specific mapping: {lambda_ranges_by_dataset}")
# Out:
# Feature selection method: lamda_tuning
# Dataset-specific lambda ranges mapped: ['madelon', 'RELATHE']
# lambda ranges for datasets without specific mapping: {'madelon': {'stg': [0.9, 1.0999905824917022, 1.3444214239671495, 1.6431676725154982, 2.0082988502465082, 2.4545664690000804, 3.0], 'lspin': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1.0, 10.0]}, 'RELATHE': {'stg': [10.0, 10.924665632994616, 11.934831919273368, 13.0384048104053, 14.244021294130647, 15.561116990763258, 17.0], 'lspin': [1e-05, 0.00014677992676220705, 0.0021544346900318843, 0.03162277660168379, 0.4641588833612782, 6.812920690579622, 100.0]}}

# %% [markdown]
# ## Dataset Paths from Local Data Folder
#
# This section resolves dataset paths for both local runs and Google Colab/Drive runs, reports which required datasets exist, and loads available `.mat` files into memory.

# %%
data_root_candidates = [
    BASE_DIR.parent / "data",
    Path(r"c:/Users/shlom/Thesis/data"),
    Path("/content/drive/MyDrive/Colab Notebooks/Thesis/data"),
    Path("/content/drive/Othercomputers/המחשב האישי שלי/Thesis/data"),
]
DATA_ROOT = next((p for p in data_root_candidates if p.exists()), data_root_candidates[0])
print(f"Data root: {DATA_ROOT}")
DATASET_PATHS = {
    "Breast": DATA_ROOT / "Challenging Data Collections" / "Unaltered Data Sources" / "Breast.mat",
    "madelon": DATA_ROOT / "Challenging Data Collections" / "Unaltered Data Sources" / "madelon.mat",
    "SMK-CAN-187": DATA_ROOT / "Standard Difficulty Data Collections" / "scikit-feature" /  "SMK-CAN-187.mat",
    "colon": DATA_ROOT / "Standard Difficulty Data Collections" / "scikit-feature" /  "colon.mat",
    "leukemia": DATA_ROOT / "Standard Difficulty Data Collections" / "scikit-feature" /  "leukemia.mat",
    "RELATHE": DATA_ROOT / "Standard Difficulty Data Collections" / "scikit-feature" / "RELATHE.mat",
}

path_status_df = pd.DataFrame(
    [{"dataset": name, "path": str(path), "exists": path.exists()} for name, path in DATASET_PATHS.items()]
)
display(path_status_df)
# Out:
# Data root: /content/drive/MyDrive/Colab Notebooks/Thesis/data
#        dataset                                               path  exists
# 0       Breast  /content/drive/MyDrive/Colab Notebooks/Thesis/...    True
# 1      madelon  /content/drive/MyDrive/Colab Notebooks/Thesis/...    True
# 2  SMK-CAN-187  /content/drive/MyDrive/Colab Notebooks/Thesis/...    True
# 3        colon  /content/drive/MyDrive/Colab Notebooks/Thesis/...    True
# 4     leukemia  /content/drive/MyDrive/Colab Notebooks/Thesis/...    True
# 5      RELATHE  /content/drive/MyDrive/Colab Notebooks/Thesis/...    True

# %% [markdown]
# ## Check and Report Dataset File Paths

# %%
from scipy.io import loadmat


def _load_mat_xy(mat_path: Path) -> tuple[np.ndarray, np.ndarray]:
    mat = loadmat(mat_path)

    feature_keys = ("X", "x", "data", "features", "fea")
    label_keys = ("y", "Y", "labels", "label", "target", "gnd")

    X = next((mat[k] for k in feature_keys if k in mat), None)
    y = next((mat[k] for k in label_keys if k in mat), None)

    if X is None or y is None:
        raise KeyError(f"Could not find feature/label keys in {mat_path.name}")

    X = np.asarray(X)
    y = np.asarray(y).reshape(-1)
    return X, y


def _load_dataset_xy(path: Path) -> tuple[np.ndarray, np.ndarray]:
    if path.suffix.lower() != ".mat":
        raise ValueError(f"Unsupported dataset format: {path.name}. Only .mat files are supported.")
    return _load_mat_xy(path)


loaded_from_data_folder = {}
missing_from_data_folder = []

for dataset_name, dataset_path in DATASET_PATHS.items():
    if dataset_path.exists():
        X, y = _load_dataset_xy(dataset_path)
        globals()[dataset_name] = (X, y)
        loaded_from_data_folder[dataset_name] = {"shape": X.shape, "labels": np.unique(y).size}
    else:
        missing_from_data_folder.append(dataset_name)

print("Loaded datasets from data folder:")
for name, meta in loaded_from_data_folder.items():
    print(f"- {name}: X shape={meta['shape']}, #classes={meta['labels']}")

if missing_from_data_folder:
    print("\nMissing datasets in data folder:", ", ".join(missing_from_data_folder))
# Out:
# Loaded datasets from data folder:
# - Breast: X shape=(97, 24481), #classes=2
# - madelon: X shape=(2600, 500), #classes=2
# - SMK-CAN-187: X shape=(187, 19993), #classes=2
# - colon: X shape=(62, 2000), #classes=2
# - leukemia: X shape=(72, 7070), #classes=2
# - RELATHE: X shape=(1427, 4322), #classes=2

# %% [markdown]
# ## Define Functions to Load .mat File Format

# %%
def set_global_seed(seed: int) -> None:
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_global_seed(SEED)
print("Global seed configured:", SEED)
# Out:
# Global seed configured: 42

# %% [markdown]
# ## Define Feature Selection and Evaluation Pipeline
# The following cells define modular functions for baseline ExtraTrees, STG, and LSPIN with 5-fold CV across iterative feature ratios: 100%, 90%, 80%, ..., 10%, and 5%.

# %%
def _as_numpy_array(value: Any) -> np.ndarray:
    if sp.issparse(value):
        return value.toarray()
    if hasattr(value, "to_numpy"):
        return value.to_numpy()
    return np.asarray(value)


def extract_xy(dataset: Any) -> Tuple[np.ndarray, np.ndarray]:
    if isinstance(dataset, (tuple, list)):
        if len(dataset) != 2:
            raise ValueError("Dataset tuple/list must have exactly (X, y).")
        return _as_numpy_array(dataset[0]), np.asarray(dataset[1])

    if isinstance(dataset, Mapping):
        feature_keys = ("X", "x", "data", "features")
        label_keys = ("y", "Y", "labels", "target", "targets")
        X = next((dataset[k] for k in feature_keys if k in dataset), None)
        y = next((dataset[k] for k in label_keys if k in dataset), None)
        if X is None or y is None:
            raise ValueError("Dataset mapping must include feature and label entries.")
        return _as_numpy_array(X), np.asarray(y)

    for feature_attr, label_attr in (("data", "target"), ("X", "y"), ("features", "labels")):
        if hasattr(dataset, feature_attr) and hasattr(dataset, label_attr):
            return _as_numpy_array(getattr(dataset, feature_attr)), np.asarray(getattr(dataset, label_attr))

    raise TypeError("Unsupported dataset format.")


def encode_labels(y: np.ndarray) -> Tuple[np.ndarray, LabelEncoder]:
    encoder = LabelEncoder()
    y_encoded = encoder.fit_transform(np.asarray(y).ravel())
    return y_encoded, encoder


def prepare_fold_arrays(X_train: np.ndarray, X_test: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    scaler = StandardScaler(with_mean=not sp.issparse(X_train))
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    if sp.issparse(X_train_scaled):
        X_train_scaled = X_train_scaled.toarray()
    if sp.issparse(X_test_scaled):
        X_test_scaled = X_test_scaled.toarray()

    return np.asarray(X_train_scaled, dtype=np.float32), np.asarray(X_test_scaled, dtype=np.float32)


def compute_auc(y_true: np.ndarray, y_proba: np.ndarray) -> float:
    y_true = np.asarray(y_true)
    y_proba = np.asarray(y_proba)

    if y_proba.ndim == 1 or y_proba.shape[1] == 1:
        return float(roc_auc_score(y_true, y_proba.ravel()))
    if y_proba.shape[1] == 2:
        return float(roc_auc_score(y_true, y_proba[:, 1]))
    return float(roc_auc_score(y_true, y_proba, multi_class="ovr", average="weighted"))


def fit_extra_trees(
    X_train: np.ndarray,
    y_train: np.ndarray,
    random_state: int,
    n_estimators: int = 200,
    max_depth: int | None = 4,
    min_samples_leaf: int = 1,
    max_features: str | float | int | None = "sqrt",
) -> ExtraTreesClassifier:
    clf = ExtraTreesClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=random_state,
        class_weight="balanced",
        n_jobs=-1,
    )
    clf.fit(X_train, y_train)
    return clf


def evaluate_classifier(clf: ExtraTreesClassifier, X_test: np.ndarray, y_test: np.ndarray) -> Dict[str, float]:
    y_pred = clf.predict(X_test)
    y_proba = clf.predict_proba(X_test)
    return {
        "auc": compute_auc(y_test, y_proba),
        "accuracy": float(accuracy_score(y_test, y_pred)),
    }


def build_feature_ratios() -> list[float]:
    ratios = [1.0] + [round(v, 2) for v in np.arange(0.9, 0.0, -0.1)] + [0.05]
    return sorted(set(ratios), reverse=True)


def build_lambda_grid(lower: float, upper: float, num_values: int = 5) -> list[float]:
    if num_values < 2:
        return [float(lower)]
    return [float(value) for value in np.geomspace(float(lower), float(upper), num=num_values)]


def ratio_to_k(p: int, ratio: float) -> int:
    return max(1, int(round(ratio * p)))


def get_checkpoint_path(dataset_name: str) -> Path:
    return OUTPUT_DIR / f"checkpoint_{dataset_name}.pkl"


def load_checkpoint(dataset_name: str) -> pd.DataFrame:
    checkpoint_path = get_checkpoint_path(dataset_name)
    if checkpoint_path.exists():
        return pd.read_pickle(checkpoint_path)
    return pd.DataFrame()


def save_checkpoint(dataset_name: str, fold_df: pd.DataFrame) -> None:
    checkpoint_path = get_checkpoint_path(dataset_name)
    fold_df.to_pickle(checkpoint_path)


def collect_loaded_datasets(namespace: MutableMapping[str, Any] | None = None, allow_partial: bool = True) -> Dict[str, Any]:
    namespace = globals() if namespace is None else namespace
    available = {name: namespace[name] for name in DEFAULT_DATASET_NAMES if name in namespace}
    missing = [name for name in DEFAULT_DATASET_NAMES if name not in namespace]

    if missing and not allow_partial:
        raise KeyError(f"Missing dataset variables: {', '.join(missing)}")

    if missing:
        print("Skipping missing datasets:", ", ".join(missing))
    return available

# %%
LAMBDA_SEQUENCE_DEFAULT = (0.1, 0.5, 1.0, 5.0, 10.0, 50.0, 100.0)


def build_lambda_sequence(
    initial_lam: float = 0.1,
    multipliers: Sequence[float] = (5.0, 2.0, 5.0, 2.0, 5.0, 2.0),
) -> list[float]:
    values = [float(initial_lam)]
    current = float(initial_lam)
    for multiplier in multipliers:
        current *= float(multiplier)
        values.append(float(current))
    return values


def _select_from_scores(
    scores: np.ndarray,
    feature_selection_method: str,
    k: int | None,
) -> tuple[np.ndarray, int]:
    scores = np.asarray(scores, dtype=np.float32).reshape(-1)
    active_indices = np.where(scores > 0)[0]
    active_count = int(active_indices.size)

    if feature_selection_method == "features_ratio":
        if k is None:
            raise ValueError("k must be provided when feature_selection_method='features_ratio'.")
        selected_indices = np.argsort(scores)[-k:][::-1]
        return selected_indices, active_count

    if feature_selection_method == "lamda_tuning":
        if active_count > 0:
            return active_indices, active_count
        fallback = np.array([int(np.argmax(scores))], dtype=np.int64)
        return fallback, 0

    raise ValueError(f"Unknown feature_selection_method: {feature_selection_method}")


def _effective_lspin_batch_size(n_samples: int, requested_batch_size: int, batch_normalization: bool) -> int:
    if requested_batch_size <= 0:
        requested_batch_size = n_samples

    batch_size = int(min(requested_batch_size, n_samples))
    if not batch_normalization:
        return max(1, batch_size)

    if n_samples <= 1:
        return 1

    if batch_size <= 1:
        return 2

    # Avoid a final mini-batch of exactly one sample when batch norm is on.
    if n_samples % batch_size == 1:
        for candidate in range(batch_size + 1, n_samples + 1):
            if n_samples % candidate != 1:
                return candidate
    return batch_size


def fit_stg_selector(
    X_train: np.ndarray,
    y_train: np.ndarray,
    k: int | None,
    random_state: int,
    feature_selection_method: str = "features_ratio",
    epochs: int = 50,
    learning_rate: float = 1e-4,
    hidden_dims: Sequence[int] = (128, 64),
    sigma: float = 0.5,
    lam: float = 0.1,
    batch_size: int = 64,
    optimizer: str = "SGD",
    activation: str = "tanh",
    early_stopping_patience: int = 25,
    early_stopping_min_delta: float = 1e-4,
    early_stopping_min_epochs: int = 50,
) -> Tuple[np.ndarray, list[float], int]:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    n_features = X_train.shape[1]
    n_classes = len(np.unique(y_train))

    selector = STG(
        device=device,
        input_dim=n_features,
        output_dim=n_classes,
        hidden_dims=list(hidden_dims),
        activation=activation,
        sigma=sigma,
        lam=lam,
        optimizer=optimizer,
        learning_rate=learning_rate,
        batch_size=batch_size,
        task_type="classification",
        random_state=random_state,
    )

    train_loader = selector.get_dataloader(X_train, y_train, shuffle=True)
    train_losses = []
    best_loss = float("inf")
    bad_epochs = 0

    for epoch_index in range(epochs):
        epoch_meters = selector.train_epoch(train_loader)
        epoch_loss = None
        if hasattr(epoch_meters, "avg") and epoch_meters.avg is not None:
            epoch_loss = epoch_meters.avg.get("loss")

        if epoch_loss is None:
            continue

        current_loss = float(epoch_loss)
        train_losses.append(current_loss)
        if current_loss < best_loss - early_stopping_min_delta:
            best_loss = current_loss
            bad_epochs = 0
        else:
            bad_epochs += 1

        if (epoch_index + 1) >= early_stopping_min_epochs and bad_epochs >= early_stopping_patience:
            print(f"STG early stopping at epoch {epoch_index + 1} (best loss={best_loss:.6f})")
            break

    gate_values = selector.get_gates("prob")
    if isinstance(gate_values, torch.Tensor):
        gate_values = gate_values.detach().cpu().numpy()
        
    gate_array = np.asarray(gate_values, dtype=np.float32).flatten()
    
    # Global STG gate extraction & active count
    active_count = int(np.sum(gate_array > 0))
    
    selected_indices, _ = _select_from_scores(gate_array, feature_selection_method, k)
    return selected_indices, train_losses, active_count


def fit_lspin_selector(
    X_train: np.ndarray,
    y_train: np.ndarray,
    k: int | None,
    random_state: int,
    feature_selection_method: str = "features_ratio",
    epochs: int = 50,
    learning_rate: float = 0.1,
    hidden_layers: Sequence[int] = (128, 64),
    gating_hidden_layers: Sequence[int] = (64,),
    sigma: float = 0.5,
    lam: float = 0.5,
    batch_size: int = 64,
    batch_normalization: bool = True,
    activation_gating: str = "tanh",
    activation_pred: str = "tanh",
    optimizer: str = "SGD",
    early_stopping_patience: int = 25,
    early_stopping_min_delta: float = 1e-4,
    early_stopping_min_epochs: int = 50,
    **_: Any,
) -> Tuple[np.ndarray, list[float], float, Any]:
    n_features = X_train.shape[1]
    labels = np.asarray(y_train).ravel()
    classes = np.unique(labels)
    class_to_index = {label: idx for idx, label in enumerate(classes)}
    y_index = np.array([class_to_index[label] for label in labels], dtype=np.int64)
    y_one_hot = np.eye(len(classes), dtype=np.float32)[y_index]
    metadata = np.zeros((X_train.shape[0], 1), dtype=np.float32)

    train_dataset = DataSetMeta(np.asarray(X_train, dtype=np.float32), y_one_hot, metadata)
    model = Lspin(
        input_node=n_features,
        hidden_layers_node=list(hidden_layers),
        output_node=len(classes),
        gating_net_hidden_layers_node=list(gating_hidden_layers),
        display_step=epochs + 1,
        activation_gating=activation_gating,
        activation_pred=activation_pred,
        feature_selection=True,
        batch_normalization=batch_normalization,
        sigma=sigma,
        lam=lam,
        seed=random_state,
        val=False,
    )

    train_losses = []
    best_loss = float("inf")
    bad_epochs = 0
    effective_batch_size = _effective_lspin_batch_size(X_train.shape[0], int(batch_size), bool(batch_normalization))

    for epoch_index in range(epochs):
        epoch_losses, _, _ = model.train_model(
            train_dataset,
            batch_size=effective_batch_size,
            num_epoch=1,
            lr=learning_rate,
            compute_sim=False,
        )
        epoch_loss = epoch_losses[-1] if epoch_losses else None
        if epoch_loss is None:
            continue

        current_loss = float(epoch_loss)
        train_losses.append(current_loss)
        if current_loss < best_loss - early_stopping_min_delta:
            best_loss = current_loss
            bad_epochs = 0
        else:
            bad_epochs += 1

        if (epoch_index + 1) >= early_stopping_min_epochs and bad_epochs >= early_stopping_patience:
            print(f"LSPIN early stopping at epoch {epoch_index + 1} (best loss={best_loss:.6f})")
            break

    gate_matrix = model.get_prob_alpha(torch.as_tensor(X_train, dtype=torch.float32, device=model.device))
    if isinstance(gate_matrix, torch.Tensor):
        gate_matrix = gate_matrix.detach().cpu().numpy()
        
    # Get the global score proxy for indice selection
    if gate_matrix.ndim == 1:
        global_scores = gate_matrix.reshape(-1)
        gate_matrix_2d = gate_matrix.reshape(1, -1)
    else:
        global_scores = gate_matrix.mean(axis=0)
        gate_matrix_2d = gate_matrix

    # Compute actual local active counts strictly > 0 per sample, then take the average
    active_counts_per_sample = np.sum(gate_matrix_2d > 0, axis=1)
    average_active_count = float(np.mean(active_counts_per_sample))

    selected_indices, _ = _select_from_scores(global_scores, feature_selection_method, k)
    return selected_indices, [float(value) for value in train_losses], average_active_count, model

def expand_loss_histories(fold_df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for row in fold_df.itertuples(index=False):
        common = {
            "dataset": row.dataset,
            "fold": int(row.fold),
            "feature_selection_method": getattr(row, "feature_selection_method", "features_ratio"),
            # Keep selection key as text for paired lambda tuning (e.g., "stg=1|lspin=10")
            "selection_value": str(getattr(row, "selection_value", "")),
            "stg_feature_ratio": float(getattr(row, "stg_feature_ratio", np.nan)),
            "lspin_feature_ratio": float(getattr(row, "lspin_feature_ratio", np.nan)),
            "lambda_value": float(getattr(row, "lambda_value", np.nan)),
            "lspin_lambda_value": float(getattr(row, "lspin_lambda_value", np.nan)),
        }

        stg_losses = list(getattr(row, "stg_train_loss_history", []) or [])
        lspin_losses = list(getattr(row, "lspin_train_loss_history", []) or [])

        for epoch_index, loss_value in enumerate(stg_losses, start=1):
            rows.append({**common, "algorithm": "STG", "epoch": epoch_index, "train_loss": float(loss_value)})
        for epoch_index, loss_value in enumerate(lspin_losses, start=1):
            rows.append({**common, "algorithm": "LSPIN", "epoch": epoch_index, "train_loss": float(loss_value)})

    return pd.DataFrame(rows)

# %%
def checkpoint_key(dataset_name: str, feature_selection_method: str, selection_value: str, fold_index: int) -> str:
    return f"{dataset_name}|{feature_selection_method}|{selection_value}|{fold_index}"


def summarize_fold_results(fold_df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    group_cols = [
        "dataset",
        "feature_selection_method",
        "selection_value",
        "lambda_value",
        "lspin_lambda_value",
        "p",
    ]

    for keys, part in fold_df.groupby(group_cols, dropna=False):
        (
            dataset_name,
            feature_selection_method,
            selection_value,
            lambda_value,
            lspin_lambda_value,
            p,
        ) = keys

        stg_k_mean = part["stg_k"].mean() if "stg_k" in part.columns else np.nan
        stg_k_value = int(round(float(stg_k_mean))) if pd.notna(stg_k_mean) else np.nan
        stg_feature_ratio_value = float(stg_k_value / int(p)) if pd.notna(stg_k_value) and int(p) > 0 else np.nan

        lspin_k_mean = part["lspin_k"].mean() if "lspin_k" in part.columns else np.nan
        lspin_k_value = int(round(float(lspin_k_mean))) if pd.notna(lspin_k_mean) else np.nan
        lspin_feature_ratio_value = float(lspin_k_value / int(p)) if pd.notna(lspin_k_value) and int(p) > 0 else np.nan

        rows.append(
            {
                "dataset": dataset_name,
                "feature_selection_method": feature_selection_method,
                "selection_value": selection_value,
                "stg_feature_ratio": stg_feature_ratio_value,
                "lspin_feature_ratio": lspin_feature_ratio_value,
                "lambda_value": float(lambda_value) if pd.notna(lambda_value) else np.nan,
                "lspin_lambda_value": float(lspin_lambda_value) if pd.notna(lspin_lambda_value) else np.nan,
                "p": int(p),
                "stg_k": stg_k_value,
                "lspin_k": lspin_k_value,
                "stg_selected_features_mean": part["stg_selected_features"].mean(),
                "lspin_selected_features_mean": part["lspin_selected_features"].mean(),
                "baseline_train_auc_mean": part["baseline_train_auc"].mean(),
                "stg_train_auc_mean": part["stg_train_auc"].mean(),
                "lspin_train_auc_mean": part["lspin_train_auc"].mean(),
                "baseline_auc_mean": part["baseline_auc"].mean(),
                "stg_auc_mean": part["stg_auc"].mean(),
                "lspin_auc_mean": part["lspin_auc"].mean(),
                "stg_auc_delta_mean": part["stg_auc_delta"].mean(),
                "lspin_auc_delta_mean": part["lspin_auc_delta"].mean(),
                "baseline_train_accuracy_mean": part["baseline_train_accuracy"].mean(),
                "stg_train_accuracy_mean": part["stg_train_accuracy"].mean(),
                "lspin_train_accuracy_mean": part["lspin_train_accuracy"].mean(),
                "baseline_accuracy_mean": part["baseline_accuracy"].mean(),
                "stg_accuracy_mean": part["stg_accuracy"].mean(),
                "lspin_accuracy_mean": part["lspin_accuracy"].mean(),
                "stg_accuracy_delta_mean": part["stg_accuracy_delta"].mean(),
                "lspin_accuracy_delta_mean": part["lspin_accuracy_delta"].mean(),
            }
        )

    sort_cols = ["dataset", "feature_selection_method", "selection_value"]
    return pd.DataFrame(rows).sort_values(sort_cols).reset_index(drop=True)



def run_fold_experiment(
    dataset_name: str,
    fold_index: int,
    X_train: np.ndarray,
    X_test: np.ndarray,
    y_train: np.ndarray,
    y_test: np.ndarray,
    random_state: int,
    stg_params: Mapping[str, Any],
    lspin_params: Mapping[str, Any],
    etree_params: Mapping[str, Any],
    feature_selection_method: str,
    selection_value: Any,
    k: int | None = None,
    ratio: float | None = None,
    lambda_value: float | None = None,
    lspin_lambda_value: float | None = None,
    run_stg: bool = True,
    run_lspin: bool = True,
) -> Dict[str, Any]:
    X_train_scaled, X_test_scaled = prepare_fold_arrays(X_train, X_test)

    baseline_model = fit_extra_trees(X_train_scaled, y_train, random_state=random_state, **dict(etree_params))
    baseline_train_metrics = evaluate_classifier(baseline_model, X_train_scaled, y_train)
    baseline_metrics = evaluate_classifier(baseline_model, X_test_scaled, y_test)

    stg_cfg = dict(stg_params)
    lspin_cfg = dict(lspin_params)

    if feature_selection_method == "lamda_tuning":
        if lambda_value is None:
            raise ValueError("lambda_value is required when feature_selection_method='lamda_tuning'.")
        stg_cfg["lam"] = float(lambda_value)
        lspin_cfg["lam"] = float(lspin_lambda_value if lspin_lambda_value is not None else lambda_value)

    if lspin_cfg.get("batch_size", 64) == -1:
        lspin_cfg["batch_size"] = X_train_scaled.shape[0]

    if run_stg:
        stg_features, stg_train_loss_history, stg_active_count = fit_stg_selector(
            X_train_scaled,
            y_train,
            k=k,
            random_state=random_state,
            feature_selection_method=feature_selection_method,
            **stg_cfg,
        )
        # Fallback to at least one feature if perfectly pruned to avoid ExtraTrees crash
        if len(stg_features) == 0:
            stg_features = [0]
            stg_active_count = 0.0 # Keep recorded metrics accurate
            
        stg_model = fit_extra_trees(X_train_scaled[:, stg_features], y_train, random_state=random_state, **dict(etree_params))
        stg_train_metrics = evaluate_classifier(stg_model, X_train_scaled[:, stg_features], y_train)
        stg_metrics = evaluate_classifier(stg_model, X_test_scaled[:, stg_features], y_test)
    else:
        stg_features, stg_train_loss_history, stg_active_count = [], [], 0
        stg_train_metrics = {"auc": np.nan, "accuracy": np.nan}
        stg_metrics = {"auc": np.nan, "accuracy": np.nan}

    if run_lspin:
        lspin_features, lspin_train_loss_history, lspin_mean_active_count, lspin_model_obj = fit_lspin_selector(
            X_train_scaled,
            y_train,
            k=k,
            random_state=random_state,
            feature_selection_method=feature_selection_method,
            **lspin_cfg,
        )
        
        # LSPIN Train Phase local masking
        train_gate_matrix = lspin_model_obj.get_prob_alpha(torch.as_tensor(X_train_scaled, dtype=torch.float32, device=lspin_model_obj.device))
        if isinstance(train_gate_matrix, torch.Tensor):
            train_gate_matrix = train_gate_matrix.detach().cpu().numpy()
            
        if train_gate_matrix.ndim == 1:
            train_gate_matrix = train_gate_matrix.reshape(1, -1)
            
        train_mask = train_gate_matrix > 0
        X_train_lspin_masked = X_train_scaled * train_mask
        
        # Drop features that are entirely pruned away by the mask across all train samples
        active_cols = np.any(train_mask, axis=0)
        
        # Fallback: keep at least one column if everything is pruned
        if not np.any(active_cols):
            active_cols[0] = True
            
        X_train_lspin_pruned = X_train_lspin_masked[:, active_cols]

        lspin_model_etree = fit_extra_trees(X_train_lspin_pruned, y_train, random_state=random_state, **dict(etree_params))
        lspin_train_metrics = evaluate_classifier(lspin_model_etree, X_train_lspin_pruned, y_train)

        # LSPIN Test Phase local masking
        test_gate_matrix = lspin_model_obj.get_prob_alpha(torch.as_tensor(X_test_scaled, dtype=torch.float32, device=lspin_model_obj.device))
        if isinstance(test_gate_matrix, torch.Tensor):
            test_gate_matrix = test_gate_matrix.detach().cpu().numpy()
            
        if test_gate_matrix.ndim == 1:
            test_gate_matrix = test_gate_matrix.reshape(1, -1)
            
        test_mask = test_gate_matrix > 0
        X_test_lspin_masked = X_test_scaled * test_mask
        
        # Apply identical pruning as used in training
        X_test_lspin_pruned = X_test_lspin_masked[:, active_cols]
        lspin_metrics = evaluate_classifier(lspin_model_etree, X_test_lspin_pruned, y_test)
    else:
        lspin_features, lspin_train_loss_history, lspin_mean_active_count, lspin_model_obj = [], [], 0, None
        lspin_train_metrics = {"auc": np.nan, "accuracy": np.nan}
        lspin_metrics = {"auc": np.nan, "accuracy": np.nan}

    p = int(X_train_scaled.shape[1])
    stg_k = int(stg_active_count)
    lspin_k = int(lspin_mean_active_count)
    
    if feature_selection_method == "features_ratio":
        stg_feature_ratio = float(stg_k / p) if p > 0 else np.nan
        lspin_feature_ratio = float(lspin_k / p) if p > 0 else np.nan
    else:
        stg_feature_ratio = float(stg_k / p) if p > 0 else np.nan
        lspin_feature_ratio = float(lspin_k / p) if p > 0 else np.nan

    return {
        "dataset": dataset_name,
        "fold": fold_index,
        "p": p,
        "stg_k": stg_k,
        "lspin_k": lspin_k,
        "feature_selection_method": feature_selection_method,
        "selection_value": selection_value,
        "stg_feature_ratio": stg_feature_ratio,
        "lspin_feature_ratio": lspin_feature_ratio,
        "lambda_value": float(lambda_value) if lambda_value is not None else np.nan,
        "lspin_lambda_value": float(lspin_lambda_value) if lspin_lambda_value is not None else np.nan,
        "stg_selected_features": int(stg_active_count),
        "lspin_selected_features": int(lspin_mean_active_count),
        "baseline_train_auc": baseline_train_metrics["auc"],
        "baseline_train_accuracy": baseline_train_metrics["accuracy"],
        "baseline_auc": baseline_metrics["auc"],
        "baseline_accuracy": baseline_metrics["accuracy"],
        "stg_train_auc": stg_train_metrics["auc"],
        "stg_train_accuracy": stg_train_metrics["accuracy"],
        "stg_auc": stg_metrics["auc"],
        "stg_accuracy": stg_metrics["accuracy"],
        "stg_train_loss_history": stg_train_loss_history,
        "lspin_train_auc": lspin_train_metrics["auc"],
        "lspin_train_accuracy": lspin_train_metrics["accuracy"],
        "lspin_auc": lspin_metrics["auc"],
        "lspin_accuracy": lspin_metrics["accuracy"],
        "lspin_train_loss_history": lspin_train_loss_history,
        "stg_auc_delta": stg_metrics["auc"] - baseline_metrics["auc"],
        "lspin_auc_delta": lspin_metrics["auc"] - baseline_metrics["auc"],
        "stg_accuracy_delta": stg_metrics["accuracy"] - baseline_metrics["accuracy"],
        "lspin_accuracy_delta": lspin_metrics["accuracy"] - baseline_metrics["accuracy"],
    }



def run_dataset_experiment(
    dataset_name: str,
    dataset: Any,
    random_state: int = 42,
    n_splits: int = 5,
    stg_params: Mapping[str, Any] | None = None,
    lspin_params: Mapping[str, Any] | None = None,
    etree_params: Mapping[str, Any] | None = None,
    feature_selection_method: str = "features_ratio",
    feature_ratios: Sequence[float] | None = None,
    lambda_values: Sequence[float] | None = None,
    stg_lambda_values: Sequence[float] | None = None,
    lspin_lambda_values: Sequence[float] | None = None,
) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    set_global_seed(random_state)
    stg_params = dict(stg_params or {})
    lspin_params = dict(lspin_params or {})
    etree_params = dict(etree_params or {})

    if feature_selection_method not in {"features_ratio", "lamda_tuning"}:
        raise ValueError("feature_selection_method must be either 'features_ratio' or 'lamda_tuning'.")

    X, y = extract_xy(dataset)
    y_encoded, _ = encode_labels(y)
    p = X.shape[1]

    if feature_selection_method == "features_ratio":
        selection_values = [float(v) for v in (feature_ratios or build_feature_ratios())]
    else:
        if stg_lambda_values is not None or lspin_lambda_values is not None:
            stg_values = [float(v) for v in (stg_lambda_values or build_lambda_sequence())]
            lspin_values = [float(v) for v in (lspin_lambda_values or build_lambda_sequence())]
            if len(stg_values) != len(lspin_values):
                raise ValueError("stg_lambda_values and lspin_lambda_values must have the same length.")
            selection_values = list(zip(stg_values, lspin_values))
        else:
            selection_values = [(float(v), float(v)) for v in (lambda_values or build_lambda_sequence())]

    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    fold_rows = []
    checkpoint_df = load_checkpoint(dataset_name)

    key_cols = {"dataset", "feature_selection_method", "selection_value", "fold"}
    if not checkpoint_df.empty and not key_cols.issubset(checkpoint_df.columns):
        print(f"Checkpoint for {dataset_name} is incompatible with current selection strategy. Rebuilding it from scratch.")
        checkpoint_df = pd.DataFrame()

    completed_keys = set()
    if not checkpoint_df.empty:
        completed_keys = {
            checkpoint_key(
                row.dataset,
                str(row.feature_selection_method),
                str(row.selection_value),
                int(row.fold),
            )
            for row in checkpoint_df.itertuples(index=False)
        }
        fold_rows.extend(checkpoint_df.to_dict(orient="records"))
        print(f"Resuming {dataset_name} from {len(completed_keys)} completed fold/selection jobs")

    stg_enabled = True
    lspin_enabled = True

    for selection_value in selection_values:
        if not stg_enabled and not lspin_enabled:
            print(f"Early stopping lambda tuning: both algorithms reached 0 features before {selection_value}")
            break

        ratio = float(selection_value) if feature_selection_method == "features_ratio" else None
        if feature_selection_method == "lamda_tuning":
            stg_lambda_value, lspin_lambda_value = selection_value if isinstance(selection_value, tuple) else (float(selection_value), float(selection_value))
            lambda_value = float(stg_lambda_value)
            selection_key = f"stg={float(stg_lambda_value):.6g}|lspin={float(lspin_lambda_value):.6g}"
        else:
            lambda_value = None
            lspin_lambda_value = None
            selection_key = f"ratio={float(selection_value):.6g}"
        k = ratio_to_k(p, ratio) if ratio is not None else None

        for fold_index, (train_idx, test_idx) in enumerate(cv.split(X, y_encoded), start=1):
            current_key = checkpoint_key(dataset_name, feature_selection_method, selection_key, fold_index)
            if current_key in completed_keys:
                continue

            fold_rows.append(
                run_fold_experiment(
                    dataset_name=dataset_name,
                    fold_index=fold_index,
                    X_train=X[train_idx],
                    X_test=X[test_idx],
                    y_train=y_encoded[train_idx],
                    y_test=y_encoded[test_idx],
                    random_state=random_state + fold_index,
                    stg_params=stg_params,
                    lspin_params=lspin_params,
                    etree_params=etree_params,
                    feature_selection_method=feature_selection_method,
                    selection_value=selection_key,
                    k=k,
                    ratio=ratio,
                    lambda_value=lambda_value,
                    lspin_lambda_value=lspin_lambda_value,
                    run_stg=stg_enabled,
                    run_lspin=lspin_enabled,
                )
            )
            save_checkpoint(dataset_name, pd.DataFrame(fold_rows))

        # Check if we should disable either STG or LSPIN individually
        if feature_selection_method == "lamda_tuning":
            current_folds = [row for row in fold_rows if row["selection_value"] == selection_key]
            if len(current_folds) == n_splits:
                if stg_enabled:
                    stg_k_avg = np.mean([row["stg_selected_features"] for row in current_folds])
                    if stg_k_avg <= 0:
                        print(f"STG selected 0 features at {selection_key}. Disabling STG for larger lambdas.")
                        stg_enabled = False
                        
                if lspin_enabled:
                    lspin_k_avg = np.mean([row["lspin_selected_features"] for row in current_folds])
                    if lspin_k_avg <= 0:
                        print(f"LSPIN selected 0 features at {selection_key}. Disabling LSPIN for larger lambdas.")
                        lspin_enabled = False

    fold_df = pd.DataFrame(fold_rows)
    loss_history_df = expand_loss_histories(fold_df)
    summary_df = summarize_fold_results(fold_df)
    return summary_df, fold_df, loss_history_df

# %% [markdown]
# ## Helper Function to Collect Loaded Datasets

# %%
def get_hyperparameters(dataset_name, X_train):
    """
    Return hyperparameters for STG, LSPIN, and ExtraTrees based on dataset group.
    """
    name = str(dataset_name).strip().lower()
    full_batch = len(X_train)
    

    # Group 1: Extreme Low Sample Size (LSS)
    lss_datasets = {"breast", "colon", "leukemia", "smk-can-187"}

    # Group 2: Medium-Large datasets
    med_large_datasets = {"madelon", "relathe"}

    if name in lss_datasets:
        stg_params = {
            "epochs": 300,
            "batch_size": 16,
            "learning_rate": 0.5,
            "lam": 1.0,
            "activation": "tanh",
            "optimizer": "SGD",
            "hidden_dims": (128, 64),
            "sigma": 0.5,
        }

        lspin_params = {
            "epochs": 300,
            "batch_size": 16,
            "learning_rate": 0.05,
            "lam": 1.0,
            "activation_gating": "tanh",
            "activation_pred": "tanh",
            "optimizer": "SGD",
            "hidden_layers": (100, 50, 30),
            "gating_hidden_layers": (100, 10),
            "sigma": 0.5,
        }

    elif name in med_large_datasets:
        if name == "relathe":
            stg_epochs = 200
            stg_batch_size = 40
            lam_stg = 10.0
            lam_lspin = 100.0
        else:  # madelon
            stg_epochs = 1000
            stg_batch_size = 200
            lam_stg = 1.0
            lam_lspin = 10.0

        stg_params = {
            "epochs": stg_epochs,
            "batch_size": stg_batch_size,
            "learning_rate": 0.05,
            "lam": lam_stg,
            "activation": "tanh",
            "optimizer": "SGD",
            "hidden_dims": (128, 64),
            "sigma": 0.5,
        }

        lspin_params = {
            "epochs": 500,
            "batch_size": 200,
            "learning_rate": 0.1,
            "lam": lam_lspin,
            "activation_gating": "tanh",
            "activation_pred": "tanh",
            "optimizer": "SGD",
            "hidden_layers": (100, 50, 30),
            "gating_hidden_layers": (500,),
            "sigma": 0.5,
        }

    else:
        raise ValueError(
            f"Unknown dataset '{dataset_name}'. "
            "Expected one of: Breast, colon, leukemia, SMK-CAN-187, madelon, RELATHE."
        )

    etree_params = {"n_estimators": 200, "max_depth": 4}
    return stg_params, lspin_params, etree_params

# %%
def plot_and_save_loss_curve(
    loss_df: pd.DataFrame,
    dataset_name: str,
    plots_dir: Path,
    title: str | None = None,
    status_prefix: str = "",
) -> None:
    if loss_df.empty:
        print(f"Loss history is missing for {dataset_name}; skipped loss plot.")
        return

    loss_summary = (
        loss_df.groupby(["algorithm", "epoch"], as_index=False)["train_loss"]
        .mean()
        .sort_values(["algorithm", "epoch"])
    )

    fig_loss, ax_loss = plt.subplots(figsize=(10, 5))
    color_by_algorithm = {"STG": "tab:orange", "LSPIN": "tab:blue"}
    for algorithm_name, algo_part in loss_summary.groupby("algorithm"):
        ax_loss.plot(
            algo_part["epoch"],
            algo_part["train_loss"],
            marker="o",
            linewidth=2,
            color=color_by_algorithm.get(algorithm_name),
            label=algorithm_name,
        )

    ax_loss.set_title(title or f"{dataset_name}: Train Loss vs Epoch")
    ax_loss.set_xlabel("Epoch")
    ax_loss.set_ylabel("Train loss")
    ax_loss.grid(True, alpha=0.3)
    ax_loss.legend()
    fig_loss.tight_layout()

    loss_plot_path = plots_dir / f"{dataset_name}_train_loss_curve.png"
    fig_loss.savefig(loss_plot_path, dpi=150, bbox_inches="tight")

    if status_prefix:
        print(f"Saved loss plot {status_prefix} {dataset_name}: {loss_plot_path}")
    else:
        print(f"Saved loss plot for {dataset_name}: {loss_plot_path}")

    plt.show()



def plot_and_save_lambda_feature_count_curve(
    summary_df: pd.DataFrame,
    dataset_name: str,
    plots_dir: Path,
) -> None:
    if summary_df.empty or "lambda_value" not in summary_df.columns:
        print(f"Lambda summary is missing for {dataset_name}; skipped lambda feature-count plot.")
        return

    part = summary_df[summary_df["dataset"] == dataset_name].copy()
    part = part[part["feature_selection_method"] == "lamda_tuning"].sort_values("lambda_value")
    if part.empty:
        print(f"No lambda-tuning rows for {dataset_name}; skipped lambda feature-count plot.")
        return

    x_positions = np.arange(len(part))
    stg_labels = [f"{v:.3g}" for v in part["lambda_value"].to_numpy()]
    lspin_labels = [f"{v:.3g}" for v in part.get("lspin_lambda_value", part["lambda_value"]).to_numpy()]

    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(x_positions, part["lspin_selected_features_mean"], marker="o", linewidth=2, color="tab:blue", label="LSPIN")
    ax.plot(x_positions, part["stg_selected_features_mean"], marker="o", linewidth=2, color="tab:orange", label="STG")
    ax.set_xlabel("STG lambda")
    ax.set_ylabel("Number of Selected Features (Gate > 0)")
    ax.set_title(f"{dataset_name}: Selected Features vs Lambda")
    ax.set_xticks(x_positions)
    ax.set_xticklabels(stg_labels, rotation=30, ha="right")
    ax.grid(True, alpha=0.3)
    ax.legend()

    ax_top = ax.twiny()
    ax_top.set_xlim(ax.get_xlim())
    ax_top.set_xticks(x_positions)
    ax_top.set_xticklabels(lspin_labels, rotation=30, ha="left")
    ax_top.set_xlabel("LSPIN lambda")

    fig.tight_layout()

    out_path = plots_dir / f"{dataset_name}_lambda_selected_features.png"
    fig.savefig(out_path, dpi=150, bbox_inches="tight")
    print(f"Saved lambda feature-count plot for {dataset_name}: {out_path}")
    plt.show()

# %% [markdown]
# ## Run Feature Selection Experiments and Save Raw Engine

# %%
plots_dir = OUTPUT_DIR / "plots"
plots_dir.mkdir(parents=True, exist_ok=True)

datasets = collect_loaded_datasets(globals(), allow_partial=True)
summary_tables: Dict[str, pd.DataFrame] = {}
fold_tables: Dict[str, pd.DataFrame] = {}
loss_tables: Dict[str, pd.DataFrame] = {}

for dataset_name, dataset in datasets.items():
    X_data, _ = extract_xy(dataset)
    stg_params, lspin_params, etree_params = get_hyperparameters(dataset_name, X_data)

    dataset_lambda_ranges = lambda_ranges_by_dataset.get(dataset_name, {"stg": lambda_values, "lspin": lambda_values})
    summary_df, fold_df, loss_df = run_dataset_experiment(
        dataset_name,
        dataset,
        random_state=SEED,
        n_splits=5,
        stg_params=stg_params,
        lspin_params=lspin_params,
        etree_params=etree_params,
        feature_selection_method=feature_selection_method,
        feature_ratios=feature_ratios,
        lambda_values=lambda_values,
        stg_lambda_values=dataset_lambda_ranges["stg"],
        lspin_lambda_values=dataset_lambda_ranges["lspin"],
    )
    summary_tables[dataset_name] = summary_df
    fold_tables[dataset_name] = fold_df
    loss_tables[dataset_name] = loss_df

    plot_and_save_loss_curve(
        loss_df=loss_df,
        dataset_name=dataset_name,
        plots_dir=plots_dir,
        title=f"{dataset_name}: Train Loss vs Epoch",
        status_prefix="right after training",
    )

    if feature_selection_method == "lamda_tuning":
        plot_and_save_lambda_feature_count_curve(
            summary_df=summary_df,
            dataset_name=dataset_name,
            plots_dir=plots_dir,
        )

    print(f"\n=== {dataset_name} summary (first rows) ===")
    display(summary_df.head())

if summary_tables:
    combined_summary_df = pd.concat(summary_tables.values(), ignore_index=True)
    combined_fold_df = pd.concat(fold_tables.values(), ignore_index=True)
    combined_loss_df = pd.concat(loss_tables.values(), ignore_index=True)
else:
    print("\nNo datasets were successfully processed. Skipping concatenation.")
    combined_summary_df = pd.DataFrame()
    combined_fold_df = pd.DataFrame()
    combined_loss_df = pd.DataFrame()

print("\nCombined summary shape:", combined_summary_df.shape)
print("Combined fold shape:", combined_fold_df.shape)
print("Combined loss shape:", combined_loss_df.shape)
display(combined_summary_df.head(10) if not combined_summary_df.empty else combined_summary_df)
# Out:
# STG early stopping at epoch 594 (best loss=0.789667)
# Training complete!
# Final Training Loss: 0.7212
# Training complete!
# Final Training Loss: 0.7024
# Training complete!
# Final Training Loss: 0.6885
# Training complete!
# Final Training Loss: 0.6769
# Training complete!
# Final Training Loss: 0.6639
# Training complete!
# Final Training Loss: 0.6600
# Training complete!
# Final Training Loss: 0.6489
# Training complete!
# Final Training Loss: 0.6394
# Training complete!
# Final Training Loss: 0.6321
# Training complete!
# Final Training Loss: 0.6209
# Training complete!
# Final Training Loss: 0.6099
# Training complete!
# Final Training Loss: 0.5976
# Training complete!
# Final Training Loss: 0.5901
# Training complete!
# Final Training Loss: 0.5814
# Training complete!
# Final Training Loss: 0.5730
# Training complete!
# Final Training Loss: 0.5660
# Training complete!
# Final Training Loss: 0.5581
# Training complete!
# Final Training Loss: 0.5459
# Training complete!
# Final Training Loss: 0.5404
# Training complete!
# Final Training Loss: 0.5311
# Training complete!
# Final Training Loss: 0.5247
# Training complete!
# Final Training Loss: 0.5174
# Training complete!
# Final Training Loss: 0.5034
# Training complete!
# Final Training Loss: 0.4953
# Training complete!
# Final Training Loss: 0.4920
# Training complete!
# Final Training Loss: 0.4879
# Training complete!
# Final Training Loss: 0.4829
# Training complete!
# Final Training Loss: 0.4761
# Training complete!
# Final Training Loss: 0.4735
# Training complete!
# Final Training Loss: 0.4641
# Training complete!
# Final Training Loss: 0.4602
# Training complete!
# Final Training Loss: 0.4587
# Training complete!
# Final Training Loss: 0.4553
# Training complete!
# Final Training Loss: 0.4499
# Training complete!
# Final Training Loss: 0.4439
# Training complete!
# Final Training Loss: 0.4458
# Training complete!
# Final Training Loss: 0.4421
# Training complete!
# Final Training Loss: 0.4402
# Training complete!
# Final Training Loss: 0.4339
# Training complete!
# Final Training Loss: 0.4334
# Training complete!
# Final Training Loss: 0.4305
# Training complete!
# Final Training Loss: 0.4285
# Training complete!
# Final Training Loss: 0.4289
# Training complete!
# Final Training Loss: 0.4252
# Training complete!
# Final Training Loss: 0.4249
# Training complete!
# Final Training Loss: 0.4241
# Training complete!
# Final Training Loss: 0.4202
# Training complete!
# Final Training Loss: 0.4206
# Training complete!
# Final Training Loss: 0.4199
# Training complete!
# Final Training Loss: 0.4183
# Training complete!
# Final Training Loss: 0.4200
# Training complete!
# Final Training Loss: 0.4169
# Training complete!
# Final Training Loss: 0.4157
# Training complete!
# Final Training Loss: 0.4144
# Training complete!
# Final Training Loss: 0.4150
# Training complete!
# Final Training Loss: 0.4126
# Training complete!
# Final Training Loss: 0.4109
# Training complete!
# Final Training Loss: 0.4121
# Training complete!
# Final Training Loss: 0.4100
# Training complete!
# Final Training Loss: 0.4101
# Training complete!
# Final Training Loss: 0.4085
# Training complete!
# Final Training Loss: 0.4072
# Training complete!
# Final Training Loss: 0.4090
# Training complete!
# Final Training Loss: 0.4081
# Training complete!
# Final Training Loss: 0.4052
# Training complete!
# Final Training Loss: 0.4061
# Training complete!
# Final Training Loss: 0.4074
# Training complete!
# Final Training Loss: 0.4048
# Training complete!
# Final Training Loss: 0.4043
# Training complete!
# Final Training Loss: 0.4036
# Training complete!
# Final Training Loss: 0.4031
# Training complete!
# Final Training Loss: 0.4027
# Training complete!
# Final Training Loss: 0.4019
# Training complete!
# Final Training Loss: 0.4023
# Training complete!
# Final Training Loss: 0.4011
# Training complete!
# Final Training Loss: 0.4015
# Training complete!
# Final Training Loss: 0.4035
# Training complete!
# Final Training Loss: 0.4001
# Training complete!
# Final Training Loss: 0.4010
# Training complete!
# Final Training Loss: 0.4010
# Training complete!
# Final Training Loss: 0.4001
# Training complete!
# Final Training Loss: 0.3996
# Training complete!
# Final Training Loss: 0.3996
# Training complete!
# Final Training Loss: 0.3986
# Training complete!
# Final Training Loss: 0.3986
# Training complete!
# Final Training Loss: 0.3975
# Training complete!
# Final Training Loss: 0.3964
# Training complete!
# Final Training Loss: 0.3978
# Training complete!
# Final Training Loss: 0.3978
# Training complete!
# Final Training Loss: 0.3975
# Training complete!
# Final Training Loss: 0.3977
# Training complete!
# Final Training Loss: 0.3977
# Training complete!
# Final Training Loss: 0.3969
# Training complete!
# Final Training Loss: 0.3982
# Training complete!
# Final Training Loss: 0.3965
# Training complete!
# Final Training Loss: 0.3960
# Training complete!
# Final Training Loss: 0.3970
# Training complete!
# Final Training Loss: 0.3968
# Training complete!
# Final Training Loss: 0.3947
# Training complete!
# Final Training Loss: 0.3974
# Training complete!
# Final Training Loss: 0.3963
# Training complete!
# Final Training Loss: 0.3960
# Training complete!
# Final Training Loss: 0.3943
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3962
# Training complete!
# Final Training Loss: 0.3950
# Training complete!
# Final Training Loss: 0.3941
# Training complete!
# Final Training Loss: 0.3943
# Training complete!
# Final Training Loss: 0.3942
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3935
# Training complete!
# Final Training Loss: 0.3945
# Training complete!
# Final Training Loss: 0.3944
# Training complete!
# Final Training Loss: 0.3952
# Training complete!
# Final Training Loss: 0.3943
# Training complete!
# Final Training Loss: 0.3938
# Training complete!
# Final Training Loss: 0.3933
# Training complete!
# Final Training Loss: 0.3936
# Training complete!
# Final Training Loss: 0.3933
# Training complete!
# Final Training Loss: 0.3934
# Training complete!
# Final Training Loss: 0.3931
# Training complete!
# Final Training Loss: 0.3944
# Training complete!
# Final Training Loss: 0.3926
# Training complete!
# Final Training Loss: 0.3931
# Training complete!
# Final Training Loss: 0.3927
# Training complete!
# Final Training Loss: 0.3929
# Training complete!
# Final Training Loss: 0.3922
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3925
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3925
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3922
# Training complete!
# Final Training Loss: 0.3927
# Training complete!
# Final Training Loss: 0.3926
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3908
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3905
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3915
# Training complete!
# Final Training Loss: 0.3909
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3905
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3913
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3898
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3898
# Training complete!
# Final Training Loss: 0.3916
# Training complete!
# Final Training Loss: 0.3909
# Training complete!
# Final Training Loss: 0.3916
# Training complete!
# Final Training Loss: 0.3903
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3903
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3890
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3901
# Training complete!
# Final Training Loss: 0.3890
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3887
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3890
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3865
# Training complete!
# Final Training Loss: 0.3867
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3865
# Training complete!
# Final Training Loss: 0.3867
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3867
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3869
# Training complete!
# Final Training Loss: 0.3866
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3866
# Training complete!
# Final Training Loss: 0.3867
# LSPIN early stopping at epoch 270 (best loss=0.386496)
# STG early stopping at epoch 605 (best loss=0.787333)
# Training complete!
# Final Training Loss: 0.7017
# Training complete!
# Final Training Loss: 0.6913
# Training complete!
# Final Training Loss: 0.6832
# Training complete!
# Final Training Loss: 0.6784
# Training complete!
# Final Training Loss: 0.6730
# Training complete!
# Final Training Loss: 0.6620
# Training complete!
# Final Training Loss: 0.6536
# Training complete!
# Final Training Loss: 0.6475
# Training complete!
# Final Training Loss: 0.6384
# Training complete!
# Final Training Loss: 0.6317
# Training complete!
# Final Training Loss: 0.6210
# Training complete!
# Final Training Loss: 0.6111
# Training complete!
# Final Training Loss: 0.6010
# Training complete!
# Final Training Loss: 0.5870
# Training complete!
# Final Training Loss: 0.5820
# Training complete!
# Final Training Loss: 0.5744
# Training complete!
# Final Training Loss: 0.5623
# Training complete!
# Final Training Loss: 0.5530
# Training complete!
# Final Training Loss: 0.5450
# Training complete!
# Final Training Loss: 0.5410
# Training complete!
# Final Training Loss: 0.5302
# Training complete!
# Final Training Loss: 0.5238
# Training complete!
# Final Training Loss: 0.5164
# Training complete!
# Final Training Loss: 0.5125
# Training complete!
# Final Training Loss: 0.5008
# Training complete!
# Final Training Loss: 0.4924
# Training complete!
# Final Training Loss: 0.4896
# Training complete!
# Final Training Loss: 0.4813
# Training complete!
# Final Training Loss: 0.4754
# Training complete!
# Final Training Loss: 0.4724
# Training complete!
# Final Training Loss: 0.4639
# Training complete!
# Final Training Loss: 0.4605
# Training complete!
# Final Training Loss: 0.4564
# Training complete!
# Final Training Loss: 0.4536
# Training complete!
# Final Training Loss: 0.4481
# Training complete!
# Final Training Loss: 0.4465
# Training complete!
# Final Training Loss: 0.4431
# Training complete!
# Final Training Loss: 0.4399
# Training complete!
# Final Training Loss: 0.4355
# Training complete!
# Final Training Loss: 0.4395
# Training complete!
# Final Training Loss: 0.4334
# Training complete!
# Final Training Loss: 0.4346
# Training complete!
# Final Training Loss: 0.4294
# Training complete!
# Final Training Loss: 0.4266
# Training complete!
# Final Training Loss: 0.4237
# Training complete!
# Final Training Loss: 0.4235
# Training complete!
# Final Training Loss: 0.4235
# Training complete!
# Final Training Loss: 0.4213
# Training complete!
# Final Training Loss: 0.4198
# Training complete!
# Final Training Loss: 0.4201
# Training complete!
# Final Training Loss: 0.4168
# Training complete!
# Final Training Loss: 0.4181
# Training complete!
# Final Training Loss: 0.4157
# Training complete!
# Final Training Loss: 0.4122
# Training complete!
# Final Training Loss: 0.4136
# Training complete!
# Final Training Loss: 0.4108
# Training complete!
# Final Training Loss: 0.4121
# Training complete!
# Final Training Loss: 0.4111
# Training complete!
# Final Training Loss: 0.4090
# Training complete!
# Final Training Loss: 0.4116
# Training complete!
# Final Training Loss: 0.4097
# Training complete!
# Final Training Loss: 0.4072
# Training complete!
# Final Training Loss: 0.4060
# Training complete!
# Final Training Loss: 0.4081
# Training complete!
# Final Training Loss: 0.4046
# Training complete!
# Final Training Loss: 0.4053
# Training complete!
# Final Training Loss: 0.4045
# Training complete!
# Final Training Loss: 0.4051
# Training complete!
# Final Training Loss: 0.4044
# Training complete!
# Final Training Loss: 0.4036
# Training complete!
# Final Training Loss: 0.4046
# Training complete!
# Final Training Loss: 0.4042
# Training complete!
# Final Training Loss: 0.4026
# Training complete!
# Final Training Loss: 0.4027
# Training complete!
# Final Training Loss: 0.4025
# Training complete!
# Final Training Loss: 0.4013
# Training complete!
# Final Training Loss: 0.4004
# Training complete!
# Final Training Loss: 0.4007
# Training complete!
# Final Training Loss: 0.3999
# Training complete!
# Final Training Loss: 0.4012
# Training complete!
# Final Training Loss: 0.4004
# Training complete!
# Final Training Loss: 0.3991
# Training complete!
# Final Training Loss: 0.3979
# Training complete!
# Final Training Loss: 0.3993
# Training complete!
# Final Training Loss: 0.3985
# Training complete!
# Final Training Loss: 0.3985
# Training complete!
# Final Training Loss: 0.3992
# Training complete!
# Final Training Loss: 0.3973
# Training complete!
# Final Training Loss: 0.3968
# Training complete!
# Final Training Loss: 0.3984
# Training complete!
# Final Training Loss: 0.3977
# Training complete!
# Final Training Loss: 0.3960
# Training complete!
# Final Training Loss: 0.3970
# Training complete!
# Final Training Loss: 0.3966
# Training complete!
# Final Training Loss: 0.3973
# Training complete!
# Final Training Loss: 0.3957
# Training complete!
# Final Training Loss: 0.3958
# Training complete!
# Final Training Loss: 0.3962
# Training complete!
# Final Training Loss: 0.3959
# Training complete!
# Final Training Loss: 0.3957
# Training complete!
# Final Training Loss: 0.3955
# Training complete!
# Final Training Loss: 0.3947
# Training complete!
# Final Training Loss: 0.3943
# Training complete!
# Final Training Loss: 0.3945
# Training complete!
# Final Training Loss: 0.3940
# Training complete!
# Final Training Loss: 0.3955
# Training complete!
# Final Training Loss: 0.3937
# Training complete!
# Final Training Loss: 0.3923
# Training complete!
# Final Training Loss: 0.3929
# Training complete!
# Final Training Loss: 0.3935
# Training complete!
# Final Training Loss: 0.3943
# Training complete!
# Final Training Loss: 0.3938
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3934
# Training complete!
# Final Training Loss: 0.3941
# Training complete!
# Final Training Loss: 0.3927
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3937
# Training complete!
# Final Training Loss: 0.3926
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3930
# Training complete!
# Final Training Loss: 0.3930
# Training complete!
# Final Training Loss: 0.3923
# Training complete!
# Final Training Loss: 0.3936
# Training complete!
# Final Training Loss: 0.3927
# Training complete!
# Final Training Loss: 0.3927
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3934
# Training complete!
# Final Training Loss: 0.3919
# Training complete!
# Final Training Loss: 0.3913
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3906
# Training complete!
# Final Training Loss: 0.3906
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3906
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3916
# Training complete!
# Final Training Loss: 0.3929
# Training complete!
# Final Training Loss: 0.3905
# Training complete!
# Final Training Loss: 0.3909
# Training complete!
# Final Training Loss: 0.3913
# Training complete!
# Final Training Loss: 0.3903
# Training complete!
# Final Training Loss: 0.3904
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3917
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3908
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3906
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3901
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3915
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3901
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3890
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3898
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3905
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3890
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3887
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3887
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3869
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3867
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3869
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3869
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3864
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3866
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3865
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3871
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3868
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3869
# LSPIN early stopping at epoch 282 (best loss=0.386428)
# STG early stopping at epoch 724 (best loss=0.769200)
# Training complete!
# Final Training Loss: 0.7126
# Training complete!
# Final Training Loss: 0.6947
# Training complete!
# Final Training Loss: 0.6835
# Training complete!
# Final Training Loss: 0.6725
# Training complete!
# Final Training Loss: 0.6661
# Training complete!
# Final Training Loss: 0.6554
# Training complete!
# Final Training Loss: 0.6503
# Training complete!
# Final Training Loss: 0.6396
# Training complete!
# Final Training Loss: 0.6251
# Training complete!
# Final Training Loss: 0.6215
# Training complete!
# Final Training Loss: 0.6116
# Training complete!
# Final Training Loss: 0.6057
# Training complete!
# Final Training Loss: 0.5877
# Training complete!
# Final Training Loss: 0.5821
# Training complete!
# Final Training Loss: 0.5685
# Training complete!
# Final Training Loss: 0.5610
# Training complete!
# Final Training Loss: 0.5522
# Training complete!
# Final Training Loss: 0.5467
# Training complete!
# Final Training Loss: 0.5357
# Training complete!
# Final Training Loss: 0.5293
# Training complete!
# Final Training Loss: 0.5211
# Training complete!
# Final Training Loss: 0.5177
# Training complete!
# Final Training Loss: 0.5107
# Training complete!
# Final Training Loss: 0.5001
# Training complete!
# Final Training Loss: 0.4954
# Training complete!
# Final Training Loss: 0.4893
# Training complete!
# Final Training Loss: 0.4858
# Training complete!
# Final Training Loss: 0.4799
# Training complete!
# Final Training Loss: 0.4690
# Training complete!
# Final Training Loss: 0.4677
# Training complete!
# Final Training Loss: 0.4648
# Training complete!
# Final Training Loss: 0.4581
# Training complete!
# Final Training Loss: 0.4555
# Training complete!
# Final Training Loss: 0.4530
# Training complete!
# Final Training Loss: 0.4520
# Training complete!
# Final Training Loss: 0.4465
# Training complete!
# Final Training Loss: 0.4436
# Training complete!
# Final Training Loss: 0.4386
# Training complete!
# Final Training Loss: 0.4363
# Training complete!
# Final Training Loss: 0.4345
# Training complete!
# Final Training Loss: 0.4355
# Training complete!
# Final Training Loss: 0.4338
# Training complete!
# Final Training Loss: 0.4296
# Training complete!
# Final Training Loss: 0.4287
# Training complete!
# Final Training Loss: 0.4246
# Training complete!
# Final Training Loss: 0.4251
# Training complete!
# Final Training Loss: 0.4232
# Training complete!
# Final Training Loss: 0.4220
# Training complete!
# Final Training Loss: 0.4177
# Training complete!
# Final Training Loss: 0.4189
# Training complete!
# Final Training Loss: 0.4158
# Training complete!
# Final Training Loss: 0.4149
# Training complete!
# Final Training Loss: 0.4143
# Training complete!
# Final Training Loss: 0.4138
# Training complete!
# Final Training Loss: 0.4107
# Training complete!
# Final Training Loss: 0.4103
# Training complete!
# Final Training Loss: 0.4108
# Training complete!
# Final Training Loss: 0.4107
# Training complete!
# Final Training Loss: 0.4115
# Training complete!
# Final Training Loss: 0.4102
# Training complete!
# Final Training Loss: 0.4091
# Training complete!
# Final Training Loss: 0.4071
# Training complete!
# Final Training Loss: 0.4068
# Training complete!
# Final Training Loss: 0.4064
# Training complete!
# Final Training Loss: 0.4054
# Training complete!
# Final Training Loss: 0.4040
# Training complete!
# Final Training Loss: 0.4051
# Training complete!
# Final Training Loss: 0.4046
# Training complete!
# Final Training Loss: 0.4046
# Training complete!
# Final Training Loss: 0.4026
# Training complete!
# Final Training Loss: 0.4035
# Training complete!
# Final Training Loss: 0.4025
# Training complete!
# Final Training Loss: 0.4030
# Training complete!
# Final Training Loss: 0.4016
# Training complete!
# Final Training Loss: 0.4017
# Training complete!
# Final Training Loss: 0.4010
# Training complete!
# Final Training Loss: 0.4020
# Training complete!
# Final Training Loss: 0.4017
# Training complete!
# Final Training Loss: 0.3991
# Training complete!
# Final Training Loss: 0.4005
# Training complete!
# Final Training Loss: 0.3995
# Training complete!
# Final Training Loss: 0.3978
# Training complete!
# Final Training Loss: 0.3983
# Training complete!
# Final Training Loss: 0.3985
# Training complete!
# Final Training Loss: 0.3999
# Training complete!
# Final Training Loss: 0.3992
# Training complete!
# Final Training Loss: 0.3971
# Training complete!
# Final Training Loss: 0.3972
# Training complete!
# Final Training Loss: 0.3977
# Training complete!
# Final Training Loss: 0.3977
# Training complete!
# Final Training Loss: 0.3962
# Training complete!
# Final Training Loss: 0.3972
# Training complete!
# Final Training Loss: 0.3983
# Training complete!
# Final Training Loss: 0.3972
# Training complete!
# Final Training Loss: 0.3953
# Training complete!
# Final Training Loss: 0.3980
# Training complete!
# Final Training Loss: 0.3983
# Training complete!
# Final Training Loss: 0.3962
# Training complete!
# Final Training Loss: 0.3953
# Training complete!
# Final Training Loss: 0.3963
# Training complete!
# Final Training Loss: 0.3965
# Training complete!
# Final Training Loss: 0.3951
# Training complete!
# Final Training Loss: 0.3956
# Training complete!
# Final Training Loss: 0.3961
# Training complete!
# Final Training Loss: 0.3963
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3955
# Training complete!
# Final Training Loss: 0.3944
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3944
# Training complete!
# Final Training Loss: 0.3942
# Training complete!
# Final Training Loss: 0.3956
# Training complete!
# Final Training Loss: 0.3952
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3936
# Training complete!
# Final Training Loss: 0.3946
# Training complete!
# Final Training Loss: 0.3923
# Training complete!
# Final Training Loss: 0.3929
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3932
# Training complete!
# Final Training Loss: 0.3925
# Training complete!
# Final Training Loss: 0.3921
# Training complete!
# Final Training Loss: 0.3922
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3917
# Training complete!
# Final Training Loss: 0.3924
# Training complete!
# Final Training Loss: 0.3921
# Training complete!
# Final Training Loss: 0.3919
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3915
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3917
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3915
# Training complete!
# Final Training Loss: 0.3904
# Training complete!
# Final Training Loss: 0.3922
# Training complete!
# Final Training Loss: 0.3919
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3916
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3908
# Training complete!
# Final Training Loss: 0.3903
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3905
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3905
# Training complete!
# Final Training Loss: 0.3903
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3903
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3887
# Training complete!
# Final Training Loss: 0.3887
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3893
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3887
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3880
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3882
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3875
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3872
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3870
# Training complete!
# Final Training Loss: 0.3877
# LSPIN early stopping at epoch 246 (best loss=0.387018)
# STG early stopping at epoch 601 (best loss=0.787417)
# Training complete!
# Final Training Loss: 0.7156
# Training complete!
# Final Training Loss: 0.6947
# Training complete!
# Final Training Loss: 0.6795
# Training complete!
# Final Training Loss: 0.6687
# Training complete!
# Final Training Loss: 0.6607
# Training complete!
# Final Training Loss: 0.6486
# Training complete!
# Final Training Loss: 0.6341
# Training complete!
# Final Training Loss: 0.6215
# Training complete!
# Final Training Loss: 0.6132
# Training complete!
# Final Training Loss: 0.6079
# Training complete!
# Final Training Loss: 0.5986
# Training complete!
# Final Training Loss: 0.5800
# Training complete!
# Final Training Loss: 0.5755
# Training complete!
# Final Training Loss: 0.5612
# Training complete!
# Final Training Loss: 0.5552
# Training complete!
# Final Training Loss: 0.5408
# Training complete!
# Final Training Loss: 0.5324
# Training complete!
# Final Training Loss: 0.5266
# Training complete!
# Final Training Loss: 0.5177
# Training complete!
# Final Training Loss: 0.5124
# Training complete!
# Final Training Loss: 0.5017
# Training complete!
# Final Training Loss: 0.4871
# Training complete!
# Final Training Loss: 0.4857
# Training complete!
# Final Training Loss: 0.4795
# Training complete!
# Final Training Loss: 0.4745
# Training complete!
# Final Training Loss: 0.4691
# Training complete!
# Final Training Loss: 0.4640
# Training complete!
# Final Training Loss: 0.4579
# Training complete!
# Final Training Loss: 0.4558
# Training complete!
# Final Training Loss: 0.4520
# Training complete!
# Final Training Loss: 0.4473
# Training complete!
# Final Training Loss: 0.4456
# Training complete!
# Final Training Loss: 0.4450
# Training complete!
# Final Training Loss: 0.4366
# Training complete!
# Final Training Loss: 0.4366
# Training complete!
# Final Training Loss: 0.4364
# Training complete!
# Final Training Loss: 0.4307
# Training complete!
# Final Training Loss: 0.4307
# Training complete!
# Final Training Loss: 0.4318
# Training complete!
# Final Training Loss: 0.4268
# Training complete!
# Final Training Loss: 0.4260
# Training complete!
# Final Training Loss: 0.4273
# Training complete!
# Final Training Loss: 0.4230
# Training complete!
# Final Training Loss: 0.4216
# Training complete!
# Final Training Loss: 0.4205
# Training complete!
# Final Training Loss: 0.4194
# Training complete!
# Final Training Loss: 0.4181
# Training complete!
# Final Training Loss: 0.4165
# Training complete!
# Final Training Loss: 0.4156
# Training complete!
# Final Training Loss: 0.4153
# Training complete!
# Final Training Loss: 0.4151
# Training complete!
# Final Training Loss: 0.4141
# Training complete!
# Final Training Loss: 0.4131
# Training complete!
# Final Training Loss: 0.4117
# Training complete!
# Final Training Loss: 0.4107
# Training complete!
# Final Training Loss: 0.4116
# Training complete!
# Final Training Loss: 0.4118
# Training complete!
# Final Training Loss: 0.4075
# Training complete!
# Final Training Loss: 0.4092
# Training complete!
# Final Training Loss: 0.4069
# Training complete!
# Final Training Loss: 0.4079
# Training complete!
# Final Training Loss: 0.4062
# Training complete!
# Final Training Loss: 0.4056
# Training complete!
# Final Training Loss: 0.4063
# Training complete!
# Final Training Loss: 0.4055
# Training complete!
# Final Training Loss: 0.4057
# Training complete!
# Final Training Loss: 0.4039
# Training complete!
# Final Training Loss: 0.4057
# Training complete!
# Final Training Loss: 0.4031
# Training complete!
# Final Training Loss: 0.4000
# Training complete!
# Final Training Loss: 0.4024
# Training complete!
# Final Training Loss: 0.4046
# Training complete!
# Final Training Loss: 0.4035
# Training complete!
# Final Training Loss: 0.4015
# Training complete!
# Final Training Loss: 0.4013
# Training complete!
# Final Training Loss: 0.4018
# Training complete!
# Final Training Loss: 0.3999
# Training complete!
# Final Training Loss: 0.4006
# Training complete!
# Final Training Loss: 0.3994
# Training complete!
# Final Training Loss: 0.3999
# Training complete!
# Final Training Loss: 0.3992
# Training complete!
# Final Training Loss: 0.3991
# Training complete!
# Final Training Loss: 0.3982
# Training complete!
# Final Training Loss: 0.3993
# Training complete!
# Final Training Loss: 0.3984
# Training complete!
# Final Training Loss: 0.3978
# Training complete!
# Final Training Loss: 0.3980
# Training complete!
# Final Training Loss: 0.3983
# Training complete!
# Final Training Loss: 0.3965
# Training complete!
# Final Training Loss: 0.3963
# Training complete!
# Final Training Loss: 0.3964
# Training complete!
# Final Training Loss: 0.3963
# Training complete!
# Final Training Loss: 0.3965
# Training complete!
# Final Training Loss: 0.3959
# Training complete!
# Final Training Loss: 0.3964
# Training complete!
# Final Training Loss: 0.3964
# Training complete!
# Final Training Loss: 0.3955
# Training complete!
# Final Training Loss: 0.3961
# Training complete!
# Final Training Loss: 0.3949
# Training complete!
# Final Training Loss: 0.3962
# Training complete!
# Final Training Loss: 0.3950
# Training complete!
# Final Training Loss: 0.3943
# Training complete!
# Final Training Loss: 0.3943
# Training complete!
# Final Training Loss: 0.3948
# Training complete!
# Final Training Loss: 0.3932
# Training complete!
# Final Training Loss: 0.3955
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3936
# Training complete!
# Final Training Loss: 0.3936
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3934
# Training complete!
# Final Training Loss: 0.3923
# Training complete!
# Final Training Loss: 0.3928
# Training complete!
# Final Training Loss: 0.3933
# Training complete!
# Final Training Loss: 0.3939
# Training complete!
# Final Training Loss: 0.3934
# Training complete!
# Final Training Loss: 0.3935
# Training complete!
# Final Training Loss: 0.3932
# Training complete!
# Final Training Loss: 0.3926
# Training complete!
# Final Training Loss: 0.3926
# Training complete!
# Final Training Loss: 0.3927
# Training complete!
# Final Training Loss: 0.3925
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3926
# Training complete!
# Final Training Loss: 0.3923
# Training complete!
# Final Training Loss: 0.3927
# Training complete!
# Final Training Loss: 0.3935
# Training complete!
# Final Training Loss: 0.3918
# Training complete!
# Final Training Loss: 0.3916
# Training complete!
# Final Training Loss: 0.3916
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3925
# Training complete!
# Final Training Loss: 0.3917
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3912
# Training complete!
# Final Training Loss: 0.3919
# Training complete!
# Final Training Loss: 0.3902
# Training complete!
# Final Training Loss: 0.3906
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3916
# Training complete!
# Final Training Loss: 0.3913
# Training complete!
# Final Training Loss: 0.3907
# Training complete!
# Final Training Loss: 0.3915
# Training complete!
# Final Training Loss: 0.3912
# Training complete!
# Final Training Loss: 0.3922
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3915
# Training complete!
# Final Training Loss: 0.3910
# Training complete!
# Final Training Loss: 0.3911
# Training complete!
# Final Training Loss: 0.3917
# Training complete!
# Final Training Loss: 0.3914
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3898
# Training complete!
# Final Training Loss: 0.3899
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3897
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3900
# Training complete!
# Final Training Loss: 0.3898
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3887
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3901
# Training complete!
# Final Training Loss: 0.3890
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3890
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3895
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3894
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3888
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3896
# Training complete!
# Final Training Loss: 0.3889
# Training complete!
# Final Training Loss: 0.3885
# Training complete!
# Final Training Loss: 0.3891
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3884
# Training complete!
# Final Training Loss: 0.3883
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3886
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3881
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3892
# Training complete!
# Final Training Loss: 0.3874
# Training complete!
# Final Training Loss: 0.3878
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3879
# Training complete!
# Final Training Loss: 0.3873
# Training complete!
# Final Training Loss: 0.3877
# Training complete!
# Final Training Loss: 0.3876
# Training complete!
# Final Training Loss: 0.3876
# ...
# Training complete!
# Final Training Loss: 25.0101
# Training complete!
# Final Training Loss: 24.8682
# Training complete!
# Final Training Loss: 24.8709
# Training complete!
# Final Training Loss: 24.7984
# Training complete!
# Final Training Loss: 24.8302
# Training complete!
# Final Training Loss: 24.6963
# Training complete!
# Final Training Loss: 24.6318
# Training complete!
# Final Training Loss: 24.7897
# Training complete!
# Final Training Loss: 24.6863
# Training complete!
# Final Training Loss: 24.5370
# Training complete!
# Final Training Loss: 24.5882
# Training complete!
# Final Training Loss: 24.6249
# Training complete!
# Final Training Loss: 24.5039
# Training complete!
# Final Training Loss: 24.4603
# Training complete!
# Final Training Loss: 24.4581
# Training complete!
# Final Training Loss: 24.5355
# Training complete!
# Final Training Loss: 24.4381
# Training complete!
# Final Training Loss: 24.4274
# Training complete!
# Final Training Loss: 24.4276
# Training complete!
# Final Training Loss: 24.3546
# Training complete!
# Final Training Loss: 24.2392
# Training complete!
# Final Training Loss: 24.2740
# Training complete!
# Final Training Loss: 24.2326
# Training complete!
# Final Training Loss: 24.1626
# Training complete!
# Final Training Loss: 24.1317
# Training complete!
# Final Training Loss: 24.1684
# Training complete!
# Final Training Loss: 24.0968
# Training complete!
# Final Training Loss: 24.0919
# Training complete!
# Final Training Loss: 24.0958
# Training complete!
# Final Training Loss: 24.0826
# Training complete!
# Final Training Loss: 24.0971
# Training complete!
# Final Training Loss: 23.9896
# Training complete!
# Final Training Loss: 23.9790
# Training complete!
# Final Training Loss: 23.9752
# Training complete!
# Final Training Loss: 23.8329
# Training complete!
# Final Training Loss: 23.9743
# Training complete!
# Final Training Loss: 23.9290
# Training complete!
# Final Training Loss: 23.7799
# Training complete!
# Final Training Loss: 23.8588
# Training complete!
# Final Training Loss: 23.7690
# Training complete!
# Final Training Loss: 23.8360
# Training complete!
# Final Training Loss: 23.8405
# Training complete!
# Final Training Loss: 23.7749
# Training complete!
# Final Training Loss: 23.7136
# Training complete!
# Final Training Loss: 23.6435
# Training complete!
# Final Training Loss: 23.7197
# Training complete!
# Final Training Loss: 23.5326
# Training complete!
# Final Training Loss: 23.6610
# Training complete!
# Final Training Loss: 23.5209
# Training complete!
# Final Training Loss: 23.5731
# Training complete!
# Final Training Loss: 23.5580
# Training complete!
# Final Training Loss: 23.5158
# Training complete!
# Final Training Loss: 23.4809
# Training complete!
# Final Training Loss: 23.5270
# Training complete!
# Final Training Loss: 23.5104
# Training complete!
# Final Training Loss: 23.4671
# Training complete!
# Final Training Loss: 23.4651
# Training complete!
# Final Training Loss: 23.2986
# Training complete!
# Final Training Loss: 23.4414
# Training complete!
# Final Training Loss: 23.4120
# Training complete!
# Final Training Loss: 23.3605
# Training complete!
# Final Training Loss: 23.3256
# Training complete!
# Final Training Loss: 23.3639
# Training complete!
# Final Training Loss: 23.3265
# Training complete!
# Final Training Loss: 23.0913
# Training complete!
# Final Training Loss: 23.2480
# Training complete!
# Final Training Loss: 23.2186
# Training complete!
# Final Training Loss: 23.1999
# Training complete!
# Final Training Loss: 23.0680
# Training complete!
# Final Training Loss: 23.1106
# Training complete!
# Final Training Loss: 23.0637
# Training complete!
# Final Training Loss: 23.0414
# Training complete!
# Final Training Loss: 23.0897
# Training complete!
# Final Training Loss: 23.1574
# Training complete!
# Final Training Loss: 23.1210
# Training complete!
# Final Training Loss: 22.9756
# Training complete!
# Final Training Loss: 22.8647
# Training complete!
# Final Training Loss: 23.0168
# Training complete!
# Final Training Loss: 23.0814
# Training complete!
# Final Training Loss: 23.0290
# Training complete!
# Final Training Loss: 22.9459
# Training complete!
# Final Training Loss: 22.8239
# Training complete!
# Final Training Loss: 22.8981
# Training complete!
# Final Training Loss: 22.8531
# Training complete!
# Final Training Loss: 22.8946
# Training complete!
# Final Training Loss: 22.9017
# Training complete!
# Final Training Loss: 22.7643
# Training complete!
# Final Training Loss: 22.7716
# Training complete!
# Final Training Loss: 22.7366
# Training complete!
# Final Training Loss: 22.6310
# Training complete!
# Final Training Loss: 22.7573
# Training complete!
# Final Training Loss: 22.7382
# Training complete!
# Final Training Loss: 22.6378
# Training complete!
# Final Training Loss: 22.7595
# Training complete!
# Final Training Loss: 22.6941
# Training complete!
# Final Training Loss: 22.6329
# Training complete!
# Final Training Loss: 22.5465
# Training complete!
# Final Training Loss: 22.5763
# Training complete!
# Final Training Loss: 22.6109
# Training complete!
# Final Training Loss: 22.6169
# Training complete!
# Final Training Loss: 22.6558
# Training complete!
# Final Training Loss: 22.6711
# Training complete!
# Final Training Loss: 22.5259
# Training complete!
# Final Training Loss: 22.5336
# Training complete!
# Final Training Loss: 22.5173
# Training complete!
# Final Training Loss: 22.5996
# Training complete!
# Final Training Loss: 22.5064
# Training complete!
# Final Training Loss: 22.4534
# Training complete!
# Final Training Loss: 22.3909
# Training complete!
# Final Training Loss: 22.4879
# Training complete!
# Final Training Loss: 22.4150
# Training complete!
# Final Training Loss: 22.3820
# Training complete!
# Final Training Loss: 22.4241
# Training complete!
# Final Training Loss: 22.4716
# Training complete!
# Final Training Loss: 22.4315
# Training complete!
# Final Training Loss: 22.3300
# Training complete!
# Final Training Loss: 22.2493
# Training complete!
# Final Training Loss: 22.2467
# Training complete!
# Final Training Loss: 22.2817
# Training complete!
# Final Training Loss: 22.3154
# Training complete!
# Final Training Loss: 22.2195
# Training complete!
# Final Training Loss: 22.2730
# Training complete!
# Final Training Loss: 22.2324
# Training complete!
# Final Training Loss: 22.2425
# Training complete!
# Final Training Loss: 22.3485
# Training complete!
# Final Training Loss: 22.3464
# Training complete!
# Final Training Loss: 22.2168
# Training complete!
# Final Training Loss: 22.2763
# Training complete!
# Final Training Loss: 22.2589
# Training complete!
# Final Training Loss: 22.2402
# Training complete!
# Final Training Loss: 22.2446
# Training complete!
# Final Training Loss: 22.1329
# Training complete!
# Final Training Loss: 22.1137
# Training complete!
# Final Training Loss: 22.0147
# Training complete!
# Final Training Loss: 22.1914
# Training complete!
# Final Training Loss: 22.2489
# Training complete!
# Final Training Loss: 22.1150
# Training complete!
# Final Training Loss: 22.0654
# Training complete!
# Final Training Loss: 22.0149
# Training complete!
# Final Training Loss: 22.1141
# Training complete!
# Final Training Loss: 22.1088
# Training complete!
# Final Training Loss: 21.9338
# Training complete!
# Final Training Loss: 21.9894
# Training complete!
# Final Training Loss: 22.0550
# Training complete!
# Final Training Loss: 22.0390
# Training complete!
# Final Training Loss: 21.8887
# Training complete!
# Final Training Loss: 21.9499
# Training complete!
# Final Training Loss: 22.0148
# Training complete!
# Final Training Loss: 21.9511
# Training complete!
# Final Training Loss: 21.9078
# Training complete!
# Final Training Loss: 21.9314
# Training complete!
# Final Training Loss: 21.9157
# Training complete!
# Final Training Loss: 21.8689
# Training complete!
# Final Training Loss: 21.8956
# Training complete!
# Final Training Loss: 21.8152
# Training complete!
# Final Training Loss: 21.8396
# Training complete!
# Final Training Loss: 21.8580
# Training complete!
# Final Training Loss: 21.8682
# Training complete!
# Final Training Loss: 21.9047
# Training complete!
# Final Training Loss: 21.7691
# Training complete!
# Final Training Loss: 21.7728
# Training complete!
# Final Training Loss: 21.7950
# Training complete!
# Final Training Loss: 21.6967
# Training complete!
# Final Training Loss: 21.7887
# Training complete!
# Final Training Loss: 21.6682
# Training complete!
# Final Training Loss: 21.7047
# Training complete!
# Final Training Loss: 21.7197
# Training complete!
# Final Training Loss: 21.6472
# Training complete!
# Final Training Loss: 21.7136
# Training complete!
# Final Training Loss: 21.6276
# Training complete!
# Final Training Loss: 21.7059
# Training complete!
# Final Training Loss: 21.6640
# Training complete!
# Final Training Loss: 21.6987
# Training complete!
# Final Training Loss: 21.6504
# Training complete!
# Final Training Loss: 21.6324
# Training complete!
# Final Training Loss: 21.5968
# Training complete!
# Final Training Loss: 21.6134
# Training complete!
# Final Training Loss: 21.5914
# Training complete!
# Final Training Loss: 21.4887
# Training complete!
# Final Training Loss: 21.5068
# Training complete!
# Final Training Loss: 21.5552
# Training complete!
# Final Training Loss: 21.5780
# Training complete!
# Final Training Loss: 21.6121
# Training complete!
# Final Training Loss: 21.5314
# Training complete!
# Final Training Loss: 21.5680
# Training complete!
# Final Training Loss: 21.5658
# Training complete!
# Final Training Loss: 21.5586
# Training complete!
# Final Training Loss: 21.5546
# Training complete!
# Final Training Loss: 21.4386
# Training complete!
# Final Training Loss: 21.4735
# Training complete!
# Final Training Loss: 21.4782
# Training complete!
# Final Training Loss: 21.5007
# Training complete!
# Final Training Loss: 21.4804
# Training complete!
# Final Training Loss: 21.3432
# Training complete!
# Final Training Loss: 21.3841
# Training complete!
# Final Training Loss: 21.4385
# Training complete!
# Final Training Loss: 21.3467
# Training complete!
# Final Training Loss: 21.3289
# Training complete!
# Final Training Loss: 21.3556
# Training complete!
# Final Training Loss: 21.3541
# Training complete!
# Final Training Loss: 21.3667
# Training complete!
# Final Training Loss: 21.4804
# Training complete!
# Final Training Loss: 21.3777
# Training complete!
# Final Training Loss: 21.3061
# Training complete!
# Final Training Loss: 21.2650
# Training complete!
# Final Training Loss: 21.3743
# Training complete!
# Final Training Loss: 21.2879
# Training complete!
# Final Training Loss: 21.3062
# Training complete!
# Final Training Loss: 21.2443
# Training complete!
# Final Training Loss: 21.2930
# Training complete!
# Final Training Loss: 21.2169
# Training complete!
# Final Training Loss: 21.1921
# Training complete!
# Final Training Loss: 21.2700
# Training complete!
# Final Training Loss: 21.2292
# Training complete!
# Final Training Loss: 21.2814
# Training complete!
# Final Training Loss: 21.2601
# Training complete!
# Final Training Loss: 21.2169
# Training complete!
# Final Training Loss: 21.3070
# Training complete!
# Final Training Loss: 21.2320
# Training complete!
# Final Training Loss: 21.1508
# Training complete!
# Final Training Loss: 21.3413
# Training complete!
# Final Training Loss: 21.0963
# Training complete!
# Final Training Loss: 21.2585
# Training complete!
# Final Training Loss: 21.3271
# Training complete!
# Final Training Loss: 21.1355
# Training complete!
# Final Training Loss: 21.0506
# Training complete!
# Final Training Loss: 21.1277
# Training complete!
# Final Training Loss: 21.1875
# Training complete!
# Final Training Loss: 21.1632
# Training complete!
# Final Training Loss: 21.0973
# Training complete!
# Final Training Loss: 21.1129
# Training complete!
# Final Training Loss: 21.0967
# Training complete!
# Final Training Loss: 21.1535
# Training complete!
# Final Training Loss: 21.1144
# Training complete!
# Final Training Loss: 21.0727
# Training complete!
# Final Training Loss: 21.0478
# Training complete!
# Final Training Loss: 21.1104
# Training complete!
# Final Training Loss: 21.0176
# Training complete!
# Final Training Loss: 20.9891
# Training complete!
# Final Training Loss: 21.0627
# Training complete!
# Final Training Loss: 21.0003
# Training complete!
# Final Training Loss: 21.0965
# Training complete!
# Final Training Loss: 21.0080
# Training complete!
# Final Training Loss: 20.9268
# Training complete!
# Final Training Loss: 21.0000
# Training complete!
# Final Training Loss: 20.9565
# Training complete!
# Final Training Loss: 20.9772
# Training complete!
# Final Training Loss: 20.9146
# Training complete!
# Final Training Loss: 20.9100
# Training complete!
# Final Training Loss: 20.9047
# Training complete!
# Final Training Loss: 20.9526
# Training complete!
# Final Training Loss: 20.8882
# Training complete!
# Final Training Loss: 20.9830
# Training complete!
# Final Training Loss: 20.8766
# Training complete!
# Final Training Loss: 20.8980
# Training complete!
# Final Training Loss: 20.8643
# Training complete!
# Final Training Loss: 20.8551
# Training complete!
# Final Training Loss: 20.8926
# Training complete!
# Final Training Loss: 20.9377
# Training complete!
# Final Training Loss: 20.8047
# Training complete!
# Final Training Loss: 20.8865
# Training complete!
# Final Training Loss: 20.7857
# Training complete!
# Final Training Loss: 20.8506
# Training complete!
# Final Training Loss: 20.8053
# Training complete!
# Final Training Loss: 20.7570
# Training complete!
# Final Training Loss: 20.8226
# Training complete!
# Final Training Loss: 20.7790
# Training complete!
# Final Training Loss: 20.7966
# Training complete!
# Final Training Loss: 20.7680
# Training complete!
# Final Training Loss: 20.8964
# Training complete!
# Final Training Loss: 20.8636
# Training complete!
# Final Training Loss: 20.7942
# Training complete!
# Final Training Loss: 20.7849
# Training complete!
# Final Training Loss: 20.7648
# Training complete!
# Final Training Loss: 20.7652
# Training complete!
# Final Training Loss: 20.7798
# Training complete!
# Final Training Loss: 20.7888
# Training complete!
# Final Training Loss: 20.7794
# Training complete!
# Final Training Loss: 20.8095
# Training complete!
# Final Training Loss: 20.7297
# Training complete!
# Final Training Loss: 20.7768
# Training complete!
# Final Training Loss: 20.7241
# Training complete!
# Final Training Loss: 20.7539
# Training complete!
# Final Training Loss: 20.6645
# Training complete!
# Final Training Loss: 20.7261
# Training complete!
# Final Training Loss: 20.7464
# Training complete!
# Final Training Loss: 20.6867
# Training complete!
# Final Training Loss: 20.6724
# Training complete!
# Final Training Loss: 20.6128
# Training complete!
# Final Training Loss: 20.6543
# Training complete!
# Final Training Loss: 20.6716
# Training complete!
# Final Training Loss: 20.6433
# Training complete!
# Final Training Loss: 20.6962
# Training complete!
# Final Training Loss: 20.5978
# Training complete!
# Final Training Loss: 20.5698
# Training complete!
# Final Training Loss: 20.6485
# Training complete!
# Final Training Loss: 20.6404
# Training complete!
# Final Training Loss: 20.6441
# Training complete!
# Final Training Loss: 20.5871
# Training complete!
# Final Training Loss: 20.6271
# Training complete!
# Final Training Loss: 20.6393
# Training complete!
# Final Training Loss: 20.6351
# Training complete!
# Final Training Loss: 20.6273
# Training complete!
# Final Training Loss: 20.5992
# Training complete!
# Final Training Loss: 20.6742
# Training complete!
# Final Training Loss: 20.5692
# Training complete!
# Final Training Loss: 20.5673
# Training complete!
# Final Training Loss: 20.5652
# Training complete!
# Final Training Loss: 20.5257
# Training complete!
# Final Training Loss: 20.4631
# Training complete!
# Final Training Loss: 20.4620
# Training complete!
# Final Training Loss: 20.5879
# Training complete!
# Final Training Loss: 20.5137
# Training complete!
# Final Training Loss: 20.5424
# Training complete!
# Final Training Loss: 20.5022
# Training complete!
# Final Training Loss: 20.4620
# Training complete!
# Final Training Loss: 20.5063
# Training complete!
# Final Training Loss: 20.4860
# Training complete!
# Final Training Loss: 20.4794
# Training complete!
# Final Training Loss: 20.5177
# Training complete!
# Final Training Loss: 20.4076
# Training complete!
# Final Training Loss: 20.4553
# Training complete!
# Final Training Loss: 20.4436
# Training complete!
# Final Training Loss: 20.4236
# Training complete!
# Final Training Loss: 20.4423
# Training complete!
# Final Training Loss: 20.4996
# Training complete!
# Final Training Loss: 20.4218
# Training complete!
# Final Training Loss: 20.4889
# Training complete!
# Final Training Loss: 20.4066
# Training complete!
# Final Training Loss: 20.3721
# Training complete!
# Final Training Loss: 20.3873
# Training complete!
# Final Training Loss: 20.3626
# Training complete!
# Final Training Loss: 20.5008

# %% [markdown]
# ## Configure Algorithm Parameters and Run Feature Selection Experiments

# %%
difficulty_by_dataset = {}
for idx, name in enumerate(DEFAULT_DATASET_NAMES):
    if idx < 1:
        difficulty_by_dataset[name] = "Hard"
    elif idx < 2:
        difficulty_by_dataset[name] = "Medium"
    else:
        difficulty_by_dataset[name] = "Easy"

plots_dir = OUTPUT_DIR / "plots"
plots_dir.mkdir(parents=True, exist_ok=True)

current_method = combined_summary_df["feature_selection_method"].dropna().iloc[0] if not combined_summary_df.empty else "features_ratio"
if current_method == "features_ratio":
    sort_col = "feature_ratio"
    x_label = "Retained features ratio (k/p)"
    x_scale = "linear"
    suffix = "feature_ratio"
else:
    sort_col = "lambda_value"
    x_label = "Number of Selected Features (Gate > 0)"
    x_scale = "linear"
    suffix = "num_features"

for dataset_name in sorted(combined_summary_df["dataset"].unique()):
    part = combined_summary_df[combined_summary_df["dataset"] == dataset_name].copy()
    part = part[part["feature_selection_method"] == current_method].sort_values(sort_col)
    difficulty = difficulty_by_dataset.get(dataset_name, "Unknown")

    if part.empty:
        continue

    if current_method == "features_ratio":
        x_stg = part["feature_ratio"]
        x_lspin = part["feature_ratio"]
        x_base = part["feature_ratio"]
    else:
        x_stg = part["stg_selected_features_mean"]
        x_lspin = part["lspin_selected_features_mean"]
        x_base = part["stg_selected_features_mean"] 

    # Test-set curves
    fig_test, axes_test = plt.subplots(1, 2, figsize=(14, 5))

    axes_test[0].plot(x_base, part["baseline_auc_mean"], marker="o", color="tab:green", label="Baseline (full-model)")
    axes_test[0].plot(x_stg, part["stg_auc_mean"], marker="o", color="tab:orange", label="STG")
    axes_test[0].plot(x_lspin, part["lspin_auc_mean"], marker="o", color="tab:blue", label="LSPIN")
    axes_test[0].set_title(f"{dataset_name} [{difficulty}]: Test AUC")
    axes_test[0].set_xlabel(x_label)
    axes_test[0].set_ylabel("AUC")
    axes_test[0].set_xscale(x_scale)
    axes_test[0].grid(True, alpha=0.3)

    axes_test[1].plot(x_base, part["baseline_accuracy_mean"], marker="o", color="tab:green", label="Baseline (full-model)")
    axes_test[1].plot(x_stg, part["stg_accuracy_mean"], marker="o", color="tab:orange", label="STG")
    axes_test[1].plot(x_lspin, part["lspin_accuracy_mean"], marker="o", color="tab:blue", label="LSPIN")
    axes_test[1].set_title(f"{dataset_name} [{difficulty}]: Test Accuracy")
    axes_test[1].set_xlabel(x_label)
    axes_test[1].set_ylabel("Accuracy")
    axes_test[1].set_xscale(x_scale)
    axes_test[1].grid(True, alpha=0.3)

    handles_test, labels_test = axes_test[1].get_legend_handles_labels()
    fig_test.legend(handles_test, labels_test, loc="lower center", ncol=3, bbox_to_anchor=(0.5, -0.05))
    fig_test.tight_layout()

    test_plot_path = plots_dir / f"{dataset_name}_test_curves_{suffix}.png"
    fig_test.savefig(test_plot_path, dpi=150, bbox_inches="tight")
    print(f"Saved test plot: {test_plot_path}")
    plt.show()

    # Train-set curves (only if present in summary columns)
    train_cols = {
        "baseline_train_auc_mean", "stg_train_auc_mean", "lspin_train_auc_mean",
        "baseline_train_accuracy_mean", "stg_train_accuracy_mean", "lspin_train_accuracy_mean",
    }
    if train_cols.issubset(part.columns):
        fig_train, axes_train = plt.subplots(1, 2, figsize=(14, 5))

        axes_train[0].plot(x_base, part["baseline_train_auc_mean"], marker="o", color="tab:green", label="Baseline (full-model)")
        axes_train[0].plot(x_stg, part["stg_train_auc_mean"], marker="o", color="tab:orange", label="STG")
        axes_train[0].plot(x_lspin, part["lspin_train_auc_mean"], marker="o", color="tab:blue", label="LSPIN")
        axes_train[0].set_title(f"{dataset_name} [{difficulty}]: Train AUC")
        axes_train[0].set_xlabel(x_label)
        axes_train[0].set_ylabel("AUC")
        axes_train[0].set_xscale(x_scale)
        axes_train[0].grid(True, alpha=0.3)

        axes_train[1].plot(x_base, part["baseline_train_accuracy_mean"], marker="o", color="tab:green", label="Baseline (full-model)")
        axes_train[1].plot(x_stg, part["stg_train_accuracy_mean"], marker="o", color="tab:orange", label="STG")
        axes_train[1].plot(x_lspin, part["lspin_train_accuracy_mean"], marker="o", color="tab:blue", label="LSPIN")
        axes_train[1].set_title(f"{dataset_name} [{difficulty}]: Train Accuracy")
        axes_train[1].set_xlabel(x_label)
        axes_train[1].set_ylabel("Accuracy")
        axes_train[1].set_xscale(x_scale)
        axes_train[1].grid(True, alpha=0.3)

        handles_train, labels_train = axes_train[1].get_legend_handles_labels()
        fig_train.legend(handles_train, labels_train, loc="lower center", ncol=3, bbox_to_anchor=(0.5, -0.05))
        fig_train.tight_layout()

        train_plot_path = plots_dir / f"{dataset_name}_train_curves_{suffix}.png"
        fig_train.savefig(train_plot_path, dpi=150, bbox_inches="tight")
        print(f"Saved train plot: {train_plot_path}")
        plt.show()
    else:
        print(f"Train-summary columns are missing for {dataset_name}; skipped train plot.")

    loss_part = combined_loss_df[combined_loss_df["dataset"] == dataset_name].copy()
    loss_part = loss_part[loss_part["feature_selection_method"] == current_method]
    if not loss_part.empty:
        loss_summary = (
            loss_part.groupby(["algorithm", "epoch"], as_index=False)["train_loss"]
            .mean()
            .sort_values(["algorithm", "epoch"])
        )
        fig_loss, ax_loss = plt.subplots(figsize=(10, 5))
        for algorithm_name, algo_part in loss_summary.groupby("algorithm"):
            color = "tab:orange" if algorithm_name == "STG" else "tab:blue"
            ax_loss.plot(
                algo_part["epoch"],
                algo_part["train_loss"],
                marker="o",
                linewidth=2,
                color=color,
                label=algorithm_name,
            )
        ax_loss.set_title(f"{dataset_name} [{difficulty}]: Train Loss vs Epoch")
        ax_loss.set_xlabel("Epoch")
        ax_loss.set_ylabel("Train loss")
        ax_loss.grid(True, alpha=0.3)
        ax_loss.legend()
        fig_loss.tight_layout()

        loss_plot_path = plots_dir / f"{dataset_name}_train_loss_curve_{suffix}.png"
        fig_loss.savefig(loss_plot_path, dpi=150, bbox_inches="tight")
        print(f"Saved loss plot: {loss_plot_path}")
        plt.show()
    else:
        print(f"Loss history is missing for {dataset_name}; skipped loss plot.")

    if current_method == "lamda_tuning" and {
        "stg_selected_features_mean", "lspin_selected_features_mean", "lambda_value"
    }.issubset(part.columns):
        x_positions = np.arange(len(part))
        stg_labels = [f"{v:.3g}" for v in part["lambda_value"].to_numpy()]
        lspin_labels = [f"{v:.3g}" for v in part.get("lspin_lambda_value", part["lambda_value"]).to_numpy()]

        fig_sel, ax_sel = plt.subplots(figsize=(10, 5))
        ax_sel.plot(x_positions, part["stg_selected_features_mean"], marker="o", linewidth=2, color="tab:orange", label="STG")
        ax_sel.plot(x_positions, part["lspin_selected_features_mean"], marker="o", linewidth=2, color="tab:blue", label="LSPIN")
        ax_sel.set_title(f"{dataset_name} [{difficulty}]: Number of Selected Features vs Lambda")
        ax_sel.set_xlabel("STG lambda")
        ax_sel.set_ylabel("Number of Selected Features (Gate > 0)")
        ax_sel.set_xticks(x_positions)
        ax_sel.set_xticklabels(stg_labels, rotation=30, ha="right")
        ax_sel.grid(True, alpha=0.3)
        ax_sel.legend()

        ax_sel_top = ax_sel.twiny()
        ax_sel_top.set_xlim(ax_sel.get_xlim())
        ax_sel_top.set_xticks(x_positions)
        ax_sel_top.set_xticklabels(lspin_labels, rotation=30, ha="left")
        ax_sel_top.set_xlabel("LSPIN lambda")

        sel_plot_path = plots_dir / f"{dataset_name}_lambda_selected_features_summary.png"
        fig_sel.savefig(sel_plot_path, dpi=150, bbox_inches="tight")
        print(f"Saved lambda selected-features plot: {sel_plot_path}")
        plt.show()
# Out:
# Saved test plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/RELATHE_test_curves_num_features.png
# Saved train plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/RELATHE_train_curves_num_features.png
# Saved loss plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/RELATHE_train_loss_curve_num_features.png
# Saved lambda selected-features plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/RELATHE_lambda_selected_features_summary.png
# Saved test plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/madelon_test_curves_num_features.png
# Saved train plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/madelon_train_curves_num_features.png
# Saved loss plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/madelon_train_loss_curve_num_features.png
# Saved lambda selected-features plot: /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/plots/madelon_lambda_selected_features_summary.png

# %% [markdown]
# ## Write Outputs to Separate Files
#
# All outputs are written to the output folder. The source ETree file is never modified.

# %%
summary_csv = OUTPUT_DIR / "iterative_feature_curve_summary.csv"
fold_csv = OUTPUT_DIR / "iterative_feature_curve_fold_results.csv"
loss_csv = OUTPUT_DIR / "iterative_feature_curve_loss_history.csv"

combined_summary_df.to_csv(summary_csv, index=False)
combined_fold_df.to_csv(fold_csv, index=False)
combined_loss_df.to_csv(loss_csv, index=False)

print("Saved:")
print("-", summary_csv)
print("-", fold_csv)
print("-", loss_csv)
# Out:
# Saved:
# - /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/iterative_feature_curve_summary.csv
# - /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/iterative_feature_curve_fold_results.csv
# - /content/drive/MyDrive/Colab Notebooks/Thesis/output/2026-04-20_16-24-11/iterative_feature_curve_loss_history.csv

# %% [markdown]
# ## Repeatable Execution Checks
#
# Run this cell anytime to quickly re-check output artifacts without rerunning model training.

# %%
import shutil


checks = {
    "summary_csv_exists": (OUTPUT_DIR / "iterative_feature_curve_summary.csv").exists(),
    "fold_csv_exists": (OUTPUT_DIR / "iterative_feature_curve_fold_results.csv").exists(),
    "loss_csv_exists": (OUTPUT_DIR / "iterative_feature_curve_loss_history.csv").exists(),
}

check_df = pd.DataFrame([checks])
display(check_df)

if not all(checks.values()):
    raise RuntimeError("One or more repeatability checks failed.")

print("All repeatability checks passed.")
import inspect

if '__file__' not in locals():
    # Get the file name of the current frame (the notebook)
    filepath = Path(os.path.basename(__vsc_ipynb_file__))
    print(f"Running in a notebook environment. Detected notebook file: {filepath}")
# handle this kind of path: "g:\האחסון שלי\Colab Notebooks\Thesis\main2.ipynb"
    filename = os.path.basename(filepath).split("\\")[-1]
    filepath = Path("/content/drive/MyDrive/Colab Notebooks/Thesis")
else:
    filepath = Path(__file__).parent
    filename = os.path.basename(__file__)


#check if filepath correct(the notebokk is in there)
notebook_files = os.listdir(filepath)
if filename not in notebook_files:
    raise RuntimeError(f"Notebook file '{filename}' not found in the notebook directory '{filepath}'. Found files: {notebook_files}")
print(f"Files in notebook directory: {notebook_files}")
shutil.copy2(os.path.join(filepath, filename), OUTPUT_DIR)
print(f"Copied notebook to output directory: {os.path.join(OUTPUT_DIR, filename)}")
# Out:
#    summary_csv_exists  fold_csv_exists  loss_csv_exists
# 0                True             True             True
# All repeatability checks passed.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_70318/1091799535.py in <cell line: 0>()
#      19 if '__file__' not in locals():
#      20     # Get the file name of the current frame (the notebook)
# ---> 21     filepath = Path(os.path.basename(__vsc_ipynb_file__))
#      22     print(f"Running in a notebook environment. Detected notebook file: {filepath}")
#      23 # handle this kind of path: "g:\האחסון שלי\Colab Notebooks\Thesis\main2.ipynb"
#
# NameError: name '__vsc_ipynb_file__' is not defined
